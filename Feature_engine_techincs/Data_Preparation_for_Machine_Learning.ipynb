# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# #***Chapter: What is Dimensionality Reduction***

# %% [markdown]
# Le nombre de variables d'entrée ou de caractéristiques d'un ensemble de données est appelé sa ***dimensionnalité***.
#
# ***La réduction de la dimensionnalité*** fait référence aux techniques qui réduisent le nombre de variables d'entrée dans un ensemble de données.
#
# Un plus grand nombre de caractéristiques d'entrée rend souvent une tâche de modélisation prédictive plus difficile à modéliser,
# Plus généralement, on parle de la malédiction de la dimensionnalité.
# Les statistiques à haute dimensionnalité et les techniques de réduction de la dimensionnalité sont souvent utilisées pour la
# visualisation des données.
#
# Néanmoins, ces techniques peuvent être utilisées en apprentissage automatique appliqué pour simplifier un ensemble de données de classification ou de régression afin de mieux adapter un modèle prédictif.
#
# Dans ce tutoriel, vous découvrirez une introduction à la réduction de la dimensionnalité pour l'apprentissage automatique.
# Après avoir lu ce tutoriel, vous saurez :
#
# **Un grand nombre de caractéristiques d'entrée peut entraîner de mauvaises performances pour les algorithmes d'apprentissage automatique.
# La réduction de la dimensionnalité est un domaine d'étude général qui vise à réduire le nombre de caractéristiques d'entrée.
# de caractéristiques d'entrée.**
#
# Les méthodes de réduction de la dimensionnalité comprennent la sélection des caractéristiques, les méthodes d'algèbre linéaire,
# les méthodes de projection et les autoencodeurs.
# Commençons.
#
# ***I) Présentation du tutoriel***
#
# Ce tutoriel est divisé en trois parties, à savoir
#
# 1. Problème avec de nombreuses variables d'entrée
# 2. Réduction de la dimensionnalité
# 3. Techniques de réduction de la dimensionnalité
#
# ***II) Problème avec de nombreuses variables d'entrée***
#
# Les performances des algorithmes d'apprentissage automatique peuvent se dégrader avec un trop grand nombre de variables d'entrée.
#
# Si vos données sont représentées par des lignes et des colonnes, comme dans une feuille de calcul, les variables d'entrée sont les colonnes qui sont introduites dans un modèle pour prédire la variable cible.
# Les variables d'entrée sont également appelées caractéristiques.
#
#
# Nous pouvons considérer que les colonnes de données représentent des dimensions dans un espace de caractéristiques à n dimensions et les lignes de données comme des points dans cet espace. Il s'agit d'une interprétation géométrique utile d'un ensemble de données.
#
# Le fait d'avoir un grand nombre de dimensions dans l'espace des caractéristiques peut signifier que le volume de cet espace est très grand et, par conséquent, les points que nous avons dans cet espace (rangées de données) représentent souvent un petit nombre de données non représentatives.
#
# Cela peut avoir un impact considérable sur les performances
# d'algorithmes d'apprentissage automatique adaptés à des données comportant de nombreuses caractéristiques d'entrée.
# malédiction de la dimensionnalité.
#
# Par conséquent, il est souvent souhaitable de réduire le nombre de caractéristiques d'entrée.Cela réduit le nombre de dimensions de l'espace des caractéristiques, d'où le nom de réduction de la dimensionnalité.
#
#
# ***III)  Réduction de la dimensionnalité***
#
# La réduction de la dimensionnalité fait référence aux techniques permettant de réduire le nombre de variables d'entrée dans les données de formation.
#
# Lorsque l'on traite des données de haute dimension, il est souvent utile de réduire la dimensionnalité en projetant les données dans un sous-espace de dimension inférieure qui capture l'essence des données.
# l'"essence" des données. C'est ce qu'on appelle ***la réduction de la dimensionnalité.***
#
# Une dimensionnalité élevée peut signifier des centaines, des milliers, voire des millions de variables d'entrée.
# **Une réduction des dimensions** d'entrée signifie souvent une réduction correspondante des paramètres ou une structure plus simple dans le modèle d'apprentissage automatique.
#
# le modèle d'apprentissage automatique, appelés degrés de liberté. Un modèle avec trop de degrés de liberté est susceptible de s'adapter excessivement à l'ensemble de données d'apprentissage et, par conséquent, de ne pas être performant sur de nouvelles données.
# nouvelles données.
#
# Il est souhaitable d'avoir des modèles simples qui généralisent bien et, par conséquent, des données d'entrée avec peu de variables.
# peu de variables d'entrée. Ceci est particulièrement vrai pour les modèles linéaires où le nombre d'entrées et les degrés de liberté du modèle sont importants.
#
# les degrés de liberté du modèle sont souvent étroitement liés.
# La raison fondamentale de la malédiction de la dimensionnalité est que les fonctions à haute dimension ont le potentiel d'être beaucoup plus efficaces que les fonctions à faible dimensionnalité.
#
# et que ces complications sont plus difficiles à discerner. La seule façon de vaincre cette
# malédiction est d'incorporer des connaissances correctes sur les données.
#
# ***La réduction de la dimensionnalité est une technique de préparation des données effectuée sur les données avant la modélisation.
# Elle peut être effectuée après le nettoyage et la mise à l'échelle des données et avant la formation d'un modèle prédictif.***
#
# ... la réduction de la dimensionnalité permet d'obtenir une représentation plus compacte et plus facilement interprétable du concept cible, en concentrant l'attention de l'utilisateur sur les variables les plus pertinentes.
#
#
# Ainsi, toute réduction de dimensionnalité effectuée sur des données de formation doit également être effectuée
# sur de nouvelles données, telles qu'un ensemble de données de test, un ensemble de données de validation et des données lors de la réalisation d'une prédiction
#
# ***IV) Techniques de réduction de la dimensionnalité***
#
# De nombreuses techniques peuvent être utilisées pour la réduction de la dimensionnalité. Dans cette section, nous
# Dans cette section, nous allons passer en revue les principales techniques.
#
# ***IV.1) Méthodes de sélection des caractéristiques***
#
# Les techniques dites de sélection des caractéristiques sont peut-être les plus courantes.
# statistiques pour sélectionner les caractéristiques à conserver et celles à supprimer.
#
# ... effectuer une sélection de caractéristiques, afin de supprimer les caractéristiques "non pertinentes" qui n'aident pas beaucoup
# au problème de la classification.
# Les deux principales classes de techniques de sélection de caractéristiques sont les méthodes enveloppantes et les méthodes de filtrage.
#
# Les méthodes enveloppantes, comme leur nom l'indique, enveloppent un modèle d'apprentissage automatique, ajustant et évaluant le modèle avec différents sous-ensembles d'entrées.
# modèle avec différents sous-ensembles de caractéristiques d'entrée et sélectionnent le sous-ensemble qui donne les meilleures performances du modèle.
#
# ***RFE est un exemple de méthode de sélection de caractéristiques enveloppantes.***
#
# Les méthodes de filtrage utilisent des méthodes de notation, telles que la corrélation entre la caractéristique et la variable cible, afin de sélectionner un sous-ensemble de caractéristiques d'entrée qui sont les plus pertinentes.
# un sous-ensemble de caractéristiques d'entrée qui sont les plus prédictives. Les exemples incluent la corrélation de Pearson et
# test du Khi-deux.
#
# ***V.2 Factorisation matricielle***
#
# Les techniques de l'algèbre linéaire peuvent être utilisées pour réduire la dimensionnalité. Plus précisément, ***les méthodes de
# de factorisation matricielle*** peuvent être utilisées pour réduire la matrice d'un ensemble de données en ses parties constituantes.
#
# Des exemples incluent la décomposition de l'aiguille et la décomposition de la valeur singulière.
#
# Les parties peuvent ensuite être classées et un sous-ensemble de ces parties peut être sélectionné pour capturer au mieux la structure saillante de la matrice qui peut être utilisée pour représenter l'ensemble de données. La méthode la plus courante pour classer les
# composantes est l'analyse en composantes principales, ou ACP en abrégé.
# La méthode la plus courante de réduction de la dimensionnalité est l'analyse en composantes principales ou ACP.
#
#
# ***V.3 Apprentissage manifold***
#
# Les techniques issues des statistiques de haute dimensionnalité peuvent également être utilisées pour la réduction de la dimensionnalité.
# En mathématiques, une projection est un type de fonction ou de mappage qui transforme les données d'une certaine manière.
#
# Ces techniques sont parfois appelées apprentissage multiple et sont utilisées pour créer une projection en basse dimension de données en haute dimension, souvent à des fins de visualisation des données.
# **La projection est conçue pour créer une représentation à faible dimension de l'ensemble de données tout en préservant au mieux la structure ou les éléments saillants des données.**
#
# Exemples de techniques d'apprentissage multidimensionnel incluent :
#
# + La carte auto-organisatrice de Kohonen (SOM).
# + Cartographie de Sammons
# + Mise à l'échelle multidimensionnelle (MDS)
# + l'intégration stochastique de voisins distribuée en t (t-SNE).
# Les caractéristiques de la projection ont souvent peu de rapport avec les colonnes d'origine, par exemple elles n'ont pas de nom de colonne, ce qui peut être déroutant pour les débutants.
#
# ***V.4 Méthodes d'autoencodage***
#
# Les réseaux neuronaux d'apprentissage profond peuvent être construits pour effectuer une réduction de la dimensionnalité. A
# approche populaire est celle des autoencodeurs. Il s'agit de formuler un problème d'apprentissage auto-supervisé dans lequel un modèle doit reproduire les données de l'utilisateur.
#
# d'apprentissage auto-supervisé où un modèle doit reproduire correctement l'entrée. On utilise un modèle de réseau qui cherche
# à comprimer le flux de données vers une couche de goulot d'étranglement avec beaucoup moins de dimensions que les données d'entrée originales.
# données d'entrée originales. **La partie du modèle qui précède et inclut le goulot d'étranglement est appelée "encodeur"
# codeur, et la partie du modèle qui lit la sortie du goulot d'étranglement et reconstruit l'entrée est appelée le décodeur.**
#
# Un auto-encodeur est un type de réseau neuronal non supervisé utilisé pour la réduction de la dimensionnalité et la découverte de caractéristiques. Plus précisément, un auto-encodeur est un
# réseau neuronal à action directe qui est formé pour prédire l'entrée elle-même.
# Après la formation, le décodeur est éliminé et la sortie du goulot d'étranglement est utilisée directement comme la dimensionnalité réduite de l'entrée.
# comme la dimensionnalité réduite de l'entrée. Les entrées transformées par cet encodeur peuvent alors être introduites dans un autre modèle, pas nécessairement un modèle neuronal.
# dans un autre modèle, pas nécessairement un modèle de réseau de neurones.
# Les autoencodeurs profonds constituent un cadre efficace pour la réduction non linéaire de la dimensionnalité.
# Une fois qu'un tel réseau a été construit, la couche la plus élevée de l'encodeur, le code
# couche hc, peut être introduite dans une procédure de classification supervisée.
# La sortie du codeur est un type de projection, et comme les autres méthodes de projection, il n'y a pas de relation directe avec le goulot d'étranglement.
# de projection, il n'y a pas de relation directe entre la sortie du goulot d'étranglement et les variables d'entrée originales, ce qui rend leur interprétation difficile.
# ce qui rend leur interprétation difficile.
#
#
# ***IV.5 Conseils pour la réduction de la dimensionnalité***
#
# Il n'existe pas de meilleure technique de réduction de la dimensionnalité ni de correspondance entre les techniques et les problèmes. Au lieu de cela, la meilleure approche consiste à utiliser des expériences contrôlées systématiques pour découvrir
# pour découvrir quelles techniques de réduction de la dimensionnalité, lorsqu'elles sont associées au modèle de votre choix, donnent les meilleures performances sur votre ensemble de données.
# En général, les méthodes d'algèbre linéaire et d'apprentissage par le manifoldsupposent que toutes les caractéristiques d'entrée ont la même échelle ou distribution. Cela suggère qu'il est
# de normaliser les données avant d'utiliser ces méthodes si les variables d'entrée ont des échelles ou des unités différentes.

# %% [markdown]
# # ***Chapter: How to Perform LDA Dimensionality Reduction***
#
# **Réduction de la dimensionnalionnalité**
#
# ***La réduction du nombre de variables d'entrée d'un modèle prédictif est appelée réduction de la dimensionnalité.***
#
# La réduction du nombre de variables d'entrée permet d'obtenir un modèle prédictif plus simple qui peut avoir de meilleures performances lors de la prédiction de nouvelles données.
#
# ***L'analyse discriminante linéaire, ou LDA en abrégé
# LDA, est un algorithme de modélisation prédictive pour la classification multi-classes.***
#
#
# Elle peut également être utilisée comme technique de réduction de la dimensionnalité, en fournissant une projection d'un ensemble de données de formation qui sépare au mieux les exemples selon la classe qui leur est attribuée.
#
# La possibilité d'utiliser l'analyse discriminante linéaire pour la réduction de la dimensionnalité surprend souvent la plupart des praticiens.
#
# Dans ce tutoriel, vous découvrirez comment utiliser LDA pour la réduction de la dimensionnalité lors du développement de modèles prédictifs.
#
# Après avoir terminé ce tutoriel, vous saurez :
#
# La réduction de la dimensionnalité consiste à réduire le nombre de variables d'entrée ou de colonnes dans les données de modélisation.
#
# LDA est une technique de classification multiclasse qui peut être utilisée pour effectuer automatiquement la réduction de la dimensionnalité.
#
# Comment évaluer les modèles prédictifs qui utilisent une projection LDA comme entrée et font des prédictions avec de nouvelles données brutes.
# Commençons.
#
# ***I) Présentation du tutoriel***
# Ce tutoriel est divisé en trois parties, à savoir :
# 1. L'analyse discriminante linéaire
# 2. LDA Scikit-Learn API
# 3. Exemple concret de LDA pour la dimensionnalité
#
#
# ***II. Analyse discriminante linéaire***
#
# ***L'analyse discriminante linéaire, ou LDA, est un algorithme linéaire d'apprentissage automatique utilisé pour la classification multi-classes.
# Elle ne doit pas être confondue avec l'allocation de Dirichlet latente (LDA), qui est également une technique de réduction de la dimensionnalité pour les textes. L'analyse discriminante linéaire
# cherche à séparer (ou à discriminer) au mieux les échantillons de l'ensemble de données d'apprentissage en fonction de leur valeur de classe.***
#
# ***Plus précisément, le modèle cherche à trouver une combinaison linéaire de variables d'entrée qui permet d'obtenir la séparation maximale des échantillons entre les classes (classe).
# séparation maximale des échantillons entre les classes (centres ou moyennes des classes) et la séparation minimale des
# séparation minimale des échantillons au sein de chaque classe.
# ... trouver la combinaison linéaire des prédicteurs telle que la variance entre groupes soit maximisée par rapport à la variance intra-groupe.***
#
# [...] trouver la combinaison des prédicteurs qui donne une séparation maximale entre les centres des données tout en minimisant la
# en même temps que l'on minimise la variation à l'intérieur de chaque groupe de données.
#
# Il existe de nombreuses façons d'encadrer et de résoudre l'algorithme LDA ; par exemple, il est courant de décrire l'algorithme LDA en termes de Bayes.
#
# **l'algorithme LDA en termes de théorème de Bayes et de probabilités conditionnelles. En pratique, le LDA pour la classification
# classification multiclasse est généralement mise en œuvre à l'aide des outils de l'algèbre linéaire et, comme l'ACP, elle utilise la factorisation matricielle à un niveau supérieur.
# PCA, utilise la factorisation matricielle au cœur de la technique. En tant que telle, une bonne pratique consiste à
# standardiser les données avant d'ajuster un modèle LDA. Maintenant que nous sommes familiarisés avec
# LDA, voyons comment nous pouvons utiliser cette approche avec le logiciel scikit-learn.**

# %% [markdown]
# ***III) LDA Scikit-Learn API***

# %%
############# Methode #################
# prepare dataset
data = ...
# define transform
lda = LinearDiscriminantAnalysis()
# prepare transform on dataset
lda.fit(data)
# apply transform to dataset
transformed = lda.transform(data)

# define the pipeline
steps = [('lda', LinearDiscriminantAnalysis()), ('m', GaussianNB())]
model = Pipeline(steps=steps)

# define the pipeline
steps = [('s', StandardScaler()), ('lda', LinearDiscriminantAnalysis()), ('m',
GaussianNB())]
model = Pipeline(steps=steps)

# %% [markdown]
# ***IV) Worked Example of LDA for Dimensionality***

# %%
# compare lda number of components with naive bayes algorithm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from matplotlib import pyplot


# get the dataset
def get_dataset():
  X, y = make_classification(n_samples=1000, n_features=20, n_informative=15,n_redundant=5, random_state=7, n_classes=10)
  return X, y


# get a list of models to evaluate
def get_models():
  models = dict()
  for i in range(1,10):
    steps = [('lda', LinearDiscriminantAnalysis(n_components=i)), ('m', GaussianNB())]
    models[str(i)] = Pipeline(steps=steps)
  return models


# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
  cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
  return scores

# define dataset
X, y = get_dataset()


# get the models to evaluate
models = get_models()

# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
  scores = evaluate_model(model, X, y)
  results.append(scores)
  names.append(name)
  print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))


# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >1 0.182 (0.032)
# >2 0.235 (0.036)
# >3 0.267 (0.038)
# >4 0.303 (0.037)
# >5 0.314 (0.049)
# >6 0.314 (0.040)
# >7 0.329 (0.042)
# >8 0.343 (0.045)
# >9 0.358 (0.056)

# %%
# make predictions using lda with naive bayes
from sklearn.datasets import make_classification
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB

# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5,
random_state=7, n_classes=10)

# define the model
steps = [('lda', LinearDiscriminantAnalysis(n_components=9)), ('m', GaussianNB())]
model = Pipeline(steps=steps)

# fit the model on the whole dataset
model.fit(X, y)

# make a single prediction
row = [[2.3548775, -1.69674567, 1.6193882, -1.19668862, -2.85422348, -2.00998376,
16.56128782, 2.57257575, 9.93779782, 0.43415008, 6.08274911, 2.12689336, 1.70100279,
3.32160983, 13.02048541, -3.05034488, 2.06346747, -3.33390362, 2.45147541, -1.23455205]]
yhat = model.predict(row)
print('Predicted Class: %d' % yhat[0])
# Out:
# Predicted Class: 6

# %% [markdown]
# #***Chapter: How to Perform PCA Dimensionality Reduction***
#
# + La réduction du nombre de variables d'entrée d'un modèle prédictif est appelée réduction de la dimensionnalité.
#
# + La réduction du nombre de variables d'entrée peut donner lieu à un modèle prédictif plus simple qui peut avoir de meilleures performances lors de la réalisation de prédictions sur de nouvelles données.
#
# + La technique la plus populaire de réduction de la réduction de la dimensionnalité dans l'apprentissage automatique est l'analyse en composantes principales (ACP).
#
# + Il s'agit d'une technique issue du domaine de l'algèbre linéaire qui peut être utilisée comme une technique de préparation des données pour créer une projection d'un ensemble de données avant l'ajustement d'un modèle.
#
# Dans ce tutoriel, vous découvrirez comment utiliser l'ACP pour réduire la dimensionnalité lors du développement de modèles prédictifs.
# modèles prédictifs. Après avoir terminé ce tutoriel, vous saurez :
# La réduction de la dimensionnalité consiste à réduire le nombre de variables d'entrée ou de colonnes dans les données de modélisation.
# données de modélisation.
#
# ***L'ACP est une technique d'algèbre linéaire qui peut être utilisée pour effectuer automatiquement la réduction de la dimensionnalité.
# réduction de la dimensionnalité.***
#
# Comment évaluer les modèles prédictifs qui utilisent une projection PCA en entrée et font des prédictions avec de nouvelles données brutes.
# avec de nouvelles données brutes.
# Commençons.
#
# ***I) Présentation du tutoriel***
#
# Ce tutoriel est divisé en trois parties :
# 1. Réduction de la dimensionnalité et ACP
# 2. API Scikit-Learn PCA
# 3. Exemple concret d'ACP pour la réduction de la dimensionnalité
#
# ***II) Réduction de la dimensionnalité et ACP***
#
# **La réduction de la dimensionnalité consiste à réduire le nombre de variables d'entrée d'un ensemble de données.**
#
# A Une approche populaire de la réduction de la dimensionnalité consiste à utiliser des techniques issues du domaine de l'algèbre linéaire.
# Cette approche est souvent appelée projection de caractéristiques et les algorithmes utilisés sont appelés méthodes de projection.
# méthodes de projection.
# L'ensemble de données résultant, la projection, peut alors être utilisé comme entrée pour former un modèle d'apprentissage automatique.
#
#
# ***L'analyse en composantes principales, ou ACP, est sans doute la technique la plus courante pour la réduction de la dimensionnalité.
# L'analyse en composantes principales ou ACP est l'approche la plus courante de la réduction de la dimensionnalité***
#
#
# Elle peut être considérée comme une méthode de projection dans laquelle les données comportant m colonnes (caractéristiques) sont projetées dans un sous-espace comportant m ou moins, tout en conservant l'essence des données d'origine.
#
#
# ***La méthode PCA peut être décrite et mise en œuvre à l'aide des outils de l'algèbre linéaire,en particulier une décomposition de matrice comme la décomposition de Eigend ou la décomposition en valeur singulière.(SVD).***
#
# ***L'ACP peut être définie comme la projection orthogonale des données sur un espace linéaire de dimension inférieure, connu sous le nom de sous-ensemble principal, de sorte que la variance des données projetées soit maximisée.
# Maintenant que nous sommes familiarisés avec l'ACP pour la réduction de la dimensionnalité, examinons comment nous pouvons utiliser cette approche avec le logiciel scikit.
# pouvons utiliser cette approche avec la bibliothèque scikit-learn.***

# %% [markdown]
# ***III) PCA Scikit-Learn API***

# %%
################ Methodologie #############
data = ...
# define transform
pca = PCA()
# prepare transform on dataset
pca.fit(data)
# apply transform to dataset
transformed = pca.transform(data)

# define the pipeline
steps = [('pca', PCA()), ('m', LogisticRegression())]
model = Pipeline(steps=steps)

#define the pipeline
steps = [('norm', MinMaxScaler()), ('pca', PCA()), ('m', LogisticRegression())]
model = Pipeline(steps=steps)

# %% [markdown]
# ***IV) Worked Example of PCA for Dimensionality Reduction***

# %%
# compare pca number of components with logistic regression algorithm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot

# get the dataset
def get_dataset():
  X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=7)
  return X, y

# get a list of models to evaluate
def get_models():
  models = dict()
  for i in range(1,21):
    steps = [('pca', PCA(n_components=i)), ('m', LogisticRegression())]
    models[str(i)] = Pipeline(steps=steps)
  return models

# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
  cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
  return scores

# define dataset
X, y = get_dataset()

# get the models to evaluate
models = get_models()


# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
  scores = evaluate_model(model, X, y)
  results.append(scores)
  names.append(name)
  print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))

# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.xticks(rotation=45)
pyplot.show()
# Out:
# >1 0.542 (0.048)
# >2 0.713 (0.048)
# >3 0.720 (0.053)
# >4 0.723 (0.051)
# >5 0.725 (0.052)
# >6 0.730 (0.046)
# >7 0.805 (0.036)
# >8 0.800 (0.037)
# >9 0.814 (0.036)
# >10 0.816 (0.034)
# >11 0.819 (0.035)
# >12 0.819 (0.038)
# >13 0.819 (0.035)
# >14 0.853 (0.029)
# >15 0.865 (0.027)
# >16 0.865 (0.027)
# >17 0.865 (0.027)
# >18 0.865 (0.027)
# >19 0.865 (0.027)
# >20 0.865 (0.027)

# %%
# make predictions using pca with logistic regression
from sklearn.datasets import make_classification
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=7)

# define the model
steps = [('pca', PCA(n_components=15)), ('m', LogisticRegression())]
model = Pipeline(steps=steps)

# fit the model on the whole dataset
model.fit(X, y)

# make a single prediction
row = [[0.2929949, -4.21223056, -1.288332, -2.17849815, -0.64527665, 2.58097719,
0.28422388, -7.1827928, -1.91211104, 2.73729512, 0.81395695, 3.96973717, -2.66939799,
3.34692332, 4.19791821, 0.99990998, -0.30201875, -4.43170633, -2.82646737, 0.44916808]]
yhat = model.predict(row)
print('Predicted Class: %d' % yhat[0])
# Out:
# Predicted Class: 1

# %% [markdown]
# # ***Chapter: How to Perform SVD Dimensionality Reduction***
#
# La réduction du nombre de variables d'entrée d'un modèle prédictif est appelée réduction de la dimensionnalité.
#
# La réduction du nombre de variables d'entrée peut donner lieu à un modèle prédictif plus simple qui peut avoir de meilleures performances lors de la réalisation de prédictions sur de nouvelles données.
#
# La technique la plus populaire pour la réduction de la dimensionnalité dans l'apprentissage automatique est la décomposition en valeurs singulières, ou SVD.
#
# Il s'agit d'une technique issue du domaine de l'algèbre linéaire qui peut être utilisée comme une technique de préparation des données pour créer une projection d'un ensemble de données éparses avant l'ajustement d'un modèle.
#
# Dans ce tutoriel, vous découvrirez comment utiliser la SVD pour réduire la dimensionnalité lors du développement de modèles prédictifs.
# modèles prédictifs. Après avoir terminé ce tutoriel, vous saurez :
# La réduction de la dimensionnalité consiste à réduire le nombre de variables d'entrée ou de colonnes dans les données de modélisation.
# données de modélisation.
#
# L'UDS est une technique d'algèbre linéaire qui peut être utilisée pour effectuer automatiquement la réduction de la dimensionnalité.
# réduction de la dimensionnalité.
#
# Comment évaluer les modèles prédictifs qui utilisent une projection UDS en entrée et font des prédictions avec de nouvelles données brutes.
# Commençons.
#
# **I)Présentation du tutoriel**
#
# Ce tutoriel est divisé en trois parties :
#
# 1. Réduction de la dimensionnalité et SVD
# 2. API Scikit-Learn d'UDS
# 3. Exemple concret de SVD pour la réduction de la dimensionnalité
#
# ***II). Réduction de la dimensionnalité et SVD***
#
# La réduction de la dimensionnalité consiste à réduire le nombre de variables d'entrée d'un ensemble de données.
#
# Une approche populaire de la réduction de la dimensionnalité consiste à utiliser des techniques issues du domaine de l'algèbre linéaire.
# Cette approche est souvent appelée projection de caractéristiques et les algorithmes utilisés sont appelés méthodes de projection.
# méthodes de projection. L'ensemble de données résultant, la projection, peut alors être utilisé comme entrée pour former un modèle d'apprentissage automatique.
#
# La décomposition en valeurs singulières, ou SVD, est peut-être la technique la plus populaire pour la réduction de la dimensionnalité lorsque les données sont spongieuses (ou parses)
#
# Les données éparses font référence à des lignes de données dont un grand nombre de valeurs sont nulles. C'est souvent le cas
# dans certains domaines, comme les systèmes de recommandation, où un utilisateur n'évalue que très peu de films ou de chansons dans la base de données  et zéro pour tous les autres cas.
#
# Un autre exemple courant est un modèle de sac de mots d'un document textuel, dans lequel le document a un compte ou une fréquence pour
# certains mots et la plupart des mots ont une valeur nulle.
#
# Exemples de données éparses appropriées pour l'application de
# SVD pour la réduction de la dimensionnalité :
#
# + Systèmes de recommandation
# + Achats client-produit
# + Compteurs d'écoute de chansons par les utilisateurs
# + Évaluations de films par les utilisateurs
# + Classification de textes
# + Codage à chaud
# + Comptage des sacs de mots
# + TF/IDF
#
# ***La méthode SVD peut être considérée comme une méthode de projection dans laquelle des données à m colonnes (caractéristiques) sont projetées dans un sous-espace à m colonnes ou moins, tout en conservant l'essence de l'original.***
#
# ***Le SVD est largement utilisé à la fois pour le calcul d'autres opérations matricielles, telles que l'inverse de la matrice, mais aussi pour la réduction des données dans l'apprentissage automatique.***
#
# ***Maintenant que nous sommes familiarisés avec SVD pour la réduction de la dimensionnalité, voyons comment utiliser cette approche avec la bibliothèque scikit-learn.***

# %% [markdown]
# ***III) Worked Example of SVD for Dimensionality***

# %%
# compare svd number of components with logistic regression algorithm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
# get the dataset
def get_dataset():
  X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=7)
  return X, y
# get a list of models to evaluate
def get_models():
  models = dict()
  for i in range(1,20):
    steps = [('svd', TruncatedSVD(n_components=i)), ('m', LogisticRegression())]
    models[str(i)] = Pipeline(steps=steps)
  return models
# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
  cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
  return scores
# define dataset
X, y = get_dataset()
# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
  scores = evaluate_model(model, X, y)
  results.append(scores)
  names.append(name)
  print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.xticks(rotation=45)
pyplot.show()
# Out:
# >1 0.542 (0.046)
# >2 0.626 (0.050)
# >3 0.719 (0.053)
# >4 0.722 (0.052)
# >5 0.721 (0.054)
# >6 0.729 (0.045)
# >7 0.802 (0.034)
# >8 0.800 (0.040)
# >9 0.814 (0.037)
# >10 0.814 (0.034)
# >11 0.817 (0.037)
# >12 0.820 (0.038)
# >13 0.820 (0.036)
# >14 0.825 (0.036)
# >15 0.865 (0.027)
# >16 0.865 (0.027)
# >17 0.865 (0.027)
# >18 0.865 (0.027)
# >19 0.865 (0.027)

# %%
# make predictions using svd with logistic regression
from sklearn.datasets import make_classification
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression

# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5,random_state=7)

# define the model
steps = [('svd', TruncatedSVD(n_components=15)), ('m', LogisticRegression())]
model = Pipeline(steps=steps)

# fit the model on the whole dataset
model.fit(X, y)

# make a single prediction
row = [[0.2929949, -4.21223056, -1.288332, -2.17849815, -0.64527665, 2.58097719,
0.28422388, -7.1827928, -1.91211104, 2.73729512, 0.81395695, 3.96973717, -2.66939799,
3.34692332, 4.19791821, 0.99990998, -0.30201875, -4.43170633, -2.82646737, 0.44916808]]

yhat= model.predict(row)
print('Predicted Class: %d' % yhat[0])
# Out:
# Predicted Class: 1

# %% [markdown]
# ***Chapter: How to Transform Numerical and Categorical Data***
#
# vous devez préparer vos données brutes en utilisant **des transformations** de données avant d'adapter un modèle d'apprentissage automatique.
#
#
# Cela est nécessaire pour garantir que vous exposez au mieux la structure de votre problème de modélisation prédictive aux algorithmes d'apprentissage.
#
# L'application de transformations de données, telles que la mise à l'échelle ou l'encodage de variables catégorielles, est simple lorsque toutes les données d'entrée sont disponibles.
#
# catégoriques est simple lorsque toutes les variables d'entrée sont du même type. Cela peut être un défi. lorsque vous disposez d'un ensemble de données de types différents et que vous souhaitez appliquer sélectivement des transformations de données à certaines caractéristiques d'entrée, mais pas à toutes.
#
#
# Heureusement, la bibliothèque d'apprentissage automatique scikit-learn Python fournit le **ColumnTransformer qui vous permet d'appliquer sélectivement des transformations de données à différentes colonnes de votre ensemble de données.**
#
# Dans ce tutoriel, vous découvrirez comment utiliser le **ColumnTransformer** pour appliquer sélectivement des transformations de données aux colonnes d'un ensemble de donnéescontenant des types de données mixtes.
#
# Après avoir terminé ce tutoriel, vous connaître :
#
# Le défi que représente l'utilisation de transformations de données avec des ensembles de données ayant des types de données mixtes.
# Comment définir, adapter et utiliser le ColumnTransformer pour appliquer sélectivement des transformations de données aux colonnes.
#
# Comment travailler sur un jeu de données réel avec des types de données mixtes et utiliser **le ColumnTransformer pour appliquer différentes transformations aux colonnes de données numériques et catégorielles.**
# Commençons.
#
# **I) Présentation du tutoriel**
#
# Ce tutoriel est divisé en trois parties :
# 1. Le défi de la transformation de différents types de données
# 2. Comment utiliser le ColumnTransformer ?
# 3. Préparation des données pour le jeu de données de régression d'Abalone
#
#
# **II) Défi de la transformation de différents types de données**
#
# Il est important de préparer les données avant la modélisation. Cela peut impliquer le remplacement de valeurs manquantes, la mise à l'échelle de valeurs numériques et le codage à chaud de données catégorielles.
#
# Les transformations de données peuvent être à l'aide de la bibliothèque scikit-learn ; par exemple, la classe SimpleImputer peut être utilisée pour remplacer les valeurs manquantes, la classe MinMaxScaler peut être utilisée pour mettre à l'échelle les valeurs numériques et la classe OneHotEncoder peut être utilisée pour coder les données catégorielles.
# OneHotEncoder peut être utilisée pour coder les variables catégorielles. Pour
#
# **1) Exemple d'application d'une seule transformation de données.**
#
# Il est également possible d'enchaîner des séquences de différentes transformations à l'aide du Pipeline. l'imputation des valeurs manquantes, puis la mise à l'échelle des valeurs numériques. Par exemple :
#
# **2) Exemple d'application d'une séquence de transformations de données.**
#
# Il est très courant de vouloir exécuter différentes techniques de préparation des données sur différentes colonnes de vos données d'entrée.
#
# **Par exemple, vous pouvez imputer les valeurs numériques manquantes avec une valeur médiane, puis mettre les valeurs à l'échelle et imputer les valeurs catégorielles manquantes en utilisant la valeur la plus fréquente et un codage à chaud de la valeur la plus fréquente et une valeur chaude pour coder les catégories.**
#
# Traditionnellement, cela vous obligerait à séparer les données numériques et catégorielles, puis à appliquer manuellement les transformations sur ces groupes de caractéristiques avant de
# afin d'ajuster et d'évaluer un modèle. Désormais, vous pouvez utiliser le ColumnTransformer pour effectuer cette opération à votre place.
#
# **3) Comment utiliser le ColumnTransformer ?**
#
# ***Le ColumnTransformer est une classe de la bibliothèque d'apprentissage automatique Python de scikit-learn qui vous permet d'appliquer de manière sélective des transformations de préparation des données.***
#
# ***Par exemple, elle vous permet d'appliquer une transformation spécifique ou une séquence de transformations aux seules colonnes numériques, et une autre aux colonnes numériques et une autre séquence de transformations aux colonnes catégorielles.
# Pour utiliser le ColumnTransformer, vous devez spécifier une liste de transformateurs.***
#
# ***Chaque transformateur est un tuple à trois éléments qui définit le
# nom du transformateur, la transformation à appliquer, et les indices de colonne à appliquer.***
#
# Pour exemple :
# - (Nom, Objet, Colonnes)
# - Par exemple, le ColumnTransformer ci-dessous applique un OneHotEncoder aux colonnes 0 et 1.

# %%
# example of using the ColumnTransformer for the Abalone dataset
from numpy import mean
from numpy import std
from numpy import absolute
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR

# load dataset
# url= https://raw.githubusercontent.com/jbrownlee/Datasets/master/abalone.csv
dataframe = read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/abalone.csv', header=None)

# split into inputs and outputs
last_ix = len(dataframe.columns) - 1
X, y = dataframe.drop(last_ix, axis=1), dataframe[last_ix]
print(X.shape, y.shape)


# determine categorical and numerical features
numerical_ix = X.select_dtypes(include=['int64', 'float64']).columns
categorical_ix = X.select_dtypes(include=['object', 'bool']).columns


# define the data preparation for the columns
t = [('cat', OneHotEncoder(), categorical_ix), ('num', MinMaxScaler(), numerical_ix)]
col_transform = ColumnTransformer(transformers=t)

print(t)

# define the model
model = SVR(kernel='rbf',gamma='scale',C=100)


# define the data preparation and modeling pipeline
pipeline = Pipeline(steps=[('prep',col_transform), ('m', model)])


# define the model cross-validation configuration
cv = KFold(n_splits=10, shuffle=True, random_state=1)


# evaluate the pipeline using cross validation and calculate MAE
scores = cross_val_score(pipeline, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# convert MAE scores to positive values
scores = absolute(scores)

# summarize the model performance
print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# (4177, 8) (4177,)
# [('cat', OneHotEncoder(), Int64Index([0], dtype='int64')), ('num', MinMaxScaler(), Int64Index([1, 2, 3, 4, 5, 6, 7], dtype='int64'))]
# MAE: 1.465 (0.047)

# %% [markdown]
# # **Chapitre: Comment transformer la cible en régression**
#
#
# La préparation des données est une partie importante de l'apprentissage automatique appliqué.
#
# Une préparation correcte de vos données de formation peut faire la différence entre des résultats médiocres et extraordinaires, même avec des algorithmes linéaires très simples.
#
# L'exécution d'opérations de préparation des données, telles que la mise à l'échelle, est relativement simple pour les variables d'entrée et a été rendue routinière en Python via la classe Pipeline
# classe scikit-learn.
#
# Dans les problèmes de modélisation prédictive par régression où une valeur numérique doit être prédite, il peut également être important de préparer les données numériques qui ne doivent pas  être prédite, il peut également être essentiel de mettre à l'échelle et d'effectuer d'autres transformations de données sur la variable cible.
#
#
# Ceci peut être réalisé en Python à l'aide de la classe ***TransformedTargetRegressor***.
#
# Dans ce tutoriel, vous découvrirez comment utiliser TransformedTargetRegressor pour mettre à l'échelle et transformer les variables cibles pour la régression à l'aide de la classe TransformedTargetRegressor, bibliothèque d'apprentissage automatique scikit-learn Python.
#
#
# Après avoir terminé ce tutoriel, vous saurez :
# L'importance de la mise à l'échelle des données d'entrée et des données cibles pour l'apprentissage automatique.
#
# Les deux approches pour appliquer des transformations de données aux variables cibles.
#
# Comment utiliser le TransformedTargetRegressor sur un ensemble de données de régression réel.
#
# Commençons.
#
# **1) Présentation du tutoriel**
#
# Ce tutoriel est divisé en trois parties :
#
# 1. Importance de la mise à l'échelle des données
# 2. Comment mettre à l'échelle les variables cibles
# 3. Exemple d'utilisation du régresseur transformé (TransformedTargetRegressor)
#
#
# **2) Importance de la mise à l'échelle des données**
#
# * Il est fréquent de disposer de données dont l'échelle des valeurs diffère d'une variable à l'autre.
#
# * Par exemple, une variable peut être exprimée en pieds, une autre en mètres, et ainsi de suite. Certains algorithmes d'apprentissage
# sont beaucoup plus performants si toutes les variables sont mises à l'échelle dans la même plage, par exemple la mise à l'échelle de toutes les variables à des valeurs comprises entre 0 et 1, appelée normalisation.
#
# * Cela affecte les algorithmes qui utilisent une somme pondérée de l'entrée, comme les modèles linéaires et les réseaux neuronaux, ainsi que les modèles qui utilisent des mesures de distance, comme les vecteurs de support et les k-voisins les plus proches.
#
# * En tant que telle, c'est une bonne pratique de mettre à l'échelle les données d'entrée, et peut-être même d'essayer d'autres transformations de données comme rendre les données plus normales (mieux adaptées à une distribution de probabilité gaussienne) à l'aide d'une transformation de puissance.
#
# * Ceci s'applique également aux variables de sortie, appelées variables cibles, telles que les valeurs numériques qui sont prédites lors de la modélisation des problèmes de modélisation prédictive par régression.
#
#
# * Pour les problèmes de régression, il est souvent souhaitable de mettre à l'échelle ou de transformer à la fois les variables d'entrée et les variables cibles.
#
# * La mise à l'échelle des variables d'entrée est simple. Dans scikit-learn, vous pouvez utiliser les objets d'échelle
# manuellement, ou le Pipeline, plus pratique, qui vous permet d'enchaîner une série d'objets de transformation de données avant d'utiliser votre modèle.
#
# * Le Pipeline ajustera les objets d'échelle sur les données de
# données d'apprentissage et appliquera la transformation aux nouvelles données, par exemple lors de l'utilisation d'un modèle pour faire une prédiction.
#
# * Par exemple :

# %%
# example of power transform input and output variables for regression.
from numpy import mean
from numpy import absolute
from numpy import loadtxt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.pipeline import Pipeline
from sklearn.linear_model import HuberRegressor
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import TransformedTargetRegressor

# load data
dataset = loadtxt('https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv', delimiter=",")

# split into inputs and outputs
X, y = dataset[:, :-1], dataset[:, -1]

# prepare the model with input scaling and power transform
steps = list()
steps.append(('scale', MinMaxScaler(feature_range=(1e-5,1))))
steps.append(('power', PowerTransformer()))
steps.append(('model', HuberRegressor()))
pipeline = Pipeline(steps=steps)

# prepare the model with target scaling
model = TransformedTargetRegressor(regressor=pipeline, transformer=PowerTransformer())


# evaluate model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# convert scores to positive
scores = absolute(scores)

# summarize the result
s_mean = mean(scores)
print('Mean MAE: %.3f' % (s_mean))
# Out:
# Mean MAE: 2.972

# %% [markdown]
# # ***Feature Selection***

# %% [markdown]
# # **Chapitre: Qu'est-ce que la sélection des caractéristiques ?**
#
# ***La sélection des caractéristiques est le processus qui consiste à réduire le nombre de variables d'entrée lors de l'élaboration d'un
# modèle prédictif.***
#
# ***Il est souhaitable de réduire le nombre de variables d'entrée pour réduire le coût de calcul de la modélisation et, dans de nombreux cas, pour améliorer les performances du modèle.***
#
# Les méthodes de sélection des caractéristiques basées sur les statistiques impliquent l'évaluation de la relation entre chaque
# variable d'entrée et la variable cible à l'aide de statistiques et de sélectionner les variables d'entrée qui ont la relation la plus forte avec la variable cible.
#
#
# Ces méthodes peuvent être rapides et efficaces, bien que le choix des mesures statistiques dépende du type de données des variables d'entrée et de sortie.
#
#
# Ainsi, il peut être difficile pour un praticien de l'apprentissage automatique de sélectionner une mesure statistique appropriée pour un ensemble de données lorsqu'il effectue une sélection de caractéristiques basée sur un filtre.
#
#
# Dans ce tutoriel, vous découvrirez comment choisir des mesures statistiques pour une sélection de données numériques et catégorielles.
#
# + ***Après avoir lu ce tutoriel, vous saurez :
#
# Il existe deux principaux types de techniques de sélection de caractéristiques : supervisée et non supervisée, et les méthodes supervisées peuvent être divisées en wrapper, filter et intrinsèque.***
#
#
# + ***Les méthodes de sélection de caractéristiques basées sur le filtre utilisent des mesures statistiques pour évaluer la corrélation ou la dépendance entre les variables d'entrée qui peuvent être filtrées pour choisir les caractéristiques les plus pertinentes.***
#
# + ***Les mesures statistiques pour la sélection des caractéristiques doivent être choisies avec soin en fonction du type de données de la variable d'entrée et de la sortie ou de l'objet de la sélection.***
#
# Commençons.
#
# **I) Présentation du tutoriel**
#
# Ce tutoriel est divisé en quatre parties :
#
# 1. Sélection des caractéristiques
#
# 2. Statistiques pour les méthodes de sélection de caractéristiques filtrantes
#
# 3. Sélection de caractéristiques avec n'importe quel type de données
#
# 4. Questions communes
#
#
#
# ***II) Sélection des caractéristiques***
#
# Les méthodes de sélection des caractéristiques ont pour but de réduire le nombre de variables d'entrée à celles qui sont considérées comme les plus utiles pour un modèle afin de prédire la variable cible.
#
# Certains problèmes de prédictifs comportent un grand nombre de variables qui peuvent ralentir le développement et l'entraînement des modèles et exiger une grande quantité de données.
#
#
# De plus, les performances de certains modèles peuvent se dégrader lorsqu'ils incluent des variables d'entrée qui ne sont pas pertinentes pour la variable cible.
#
# De nombreux modèles, en particulier ceux basés sur les pentes et les intercepts de régression, estiment les paramètres pour chaque terme du modèle.
# paramètres pour chaque terme du modèle. De ce fait, la présence de variables non informatives peut ajouter de l'incertitude aux prédictions et réduire l'efficacité globale du modèle.
#
#
# Une façon de penser aux méthodes de sélection des caractéristiques est de les considérer en termes de méthodes supervisées et non supervisées.
#
# La différence réside dans le fait que les caractéristiques sont sélectionnées en fonction de la variable cible ou non.
# variable cible ou non.
#
# + **Sélection non supervisée** : N'utilisez pas la variable cible (par exemple, supprimez les variables redondantes).
#
# + **Sélection supervisée** : Utiliser la variable cible (par exemple, supprimer les variables non pertinentes).
#
#
# + Les techniques de sélection de caractéristiques non supervisées ignorent la variable cible, comme les méthodes qui suppriment les variables redondantes en utilisant la corrélation ou les caractéristiques qui ont peu de valeurs ou une faible variance (c'est-à-dire le nettoyage des données).
#
# + Les techniques de sélection de caractéristiques supervisées utilisent la variable cible, telles que les méthodes qui éliminent les variables non pertinentes.
#
# Une distinction importante à faire dans la sélection des caractéristiques est celle des méthodes supervisées et non supervisées.
#
# Lorsque le résultat est ignoré lors de l'élimination des prédicteurs, la technique est non supervisée.
#
#
# Les méthodes supervisées de sélection de caractéristiques peuvent en outre être classées en trois groupes, à savoir.
#
# **les méthodes intrinsèques, enveloppantes et filtrantes.**
#
# + **Intrinsèque** : Algorithmes qui effectuent une sélection automatique des caractéristiques pendant la formation.
#
# + **Filtre** : Sélectionnent des sous-ensembles de caractéristiques en fonction de leur relation avec la cible.
#
# + **Wrapper** : Recherche de sous-ensembles de caractéristiques qui fonctionnent selon un modèle prédictif.
#
# + Les méthodes de sélection de caractéristiques enveloppantes créent de nombreux modèles avec différents sous-ensembles de caractéristiques d'entrée et sélectionnent les caractéristiques qui donnent le modèle le plus performant selon une mesure de performance.
#
# + Ces méthodes ne se soucient pas des types de variables, bien qu'elles puissent être coûteuses en calcul.
#
# **III) Statistiques pour la sélection des caractéristiques**
#
# Il est courant d'utiliser des mesures statistiques de type corrélation entre les variables d'entrée et de sortie comme base de la sélection des caractéristiques du filtre.
#
# En tant que tel, le choix des mesures statistiques dépend fortement des types de données variables.
#
# **Les types de données courants comprennent les données numériques (telles que hauteur) et catégoriques (comme une étiquette), bien que chacun puisse être subdivisé comme suit**
#
# + entiers et à virgule flottante pour les variables numériques
#
# + booléens, ordinaux ou nominaux pour les variables catégorielles.
#
# Les variables d'entrée sont celles qui sont fournies en entrée d'un modèle.
# Dans la sélection des caractéristiques, c'est ce groupe de variables que l'on souhaite réduire en taille. Les variables de sortie sont celles pour lesquelles un modèle est destiné à prédire, souvent appelées variables de réponse.
#
# + Variable d'entrée : Variables utilisées en entrée d'un modèle prédictif.
#
# + Variable de sortie : Variables de sortie ou prédites par un modèle (cible).
#
# + Le type de variable de réponse indique typiquement le type de problème de modélisation prédictive qui est réalisé.
#
# + Par exemple, une variable de sortie numérique indique un problème de modélisation prédictive de régression, et une variable de sortie catégorielle indique un problème de modélisation prédictive de régression.
#
# + régression, et une variable de sortie catégorielle indique un problème de modélisation prédictive de classification.
#
# **III) Statistiques pour la sélection de caractéristiques**
#
# + **Sortie numérique** : Problème de modélisation prédictive de régression.
#
# + **Sortie catégorielle** : Problème de modélisation prédictive de classification.
#
#
# Les mesures statistiques utilisées dans la sélection de caractéristiques par filtre sont généralement calculées une
# variable d'entrée à la fois avec la variable cible.
#
# En tant que telles, elles sont appelées mesures statistiques univariées.
# mesures statistiques univariées. Cela peut signifier que toute interaction entre les variables d'entrée n'est pas prise en compte dans le processus de filtrage.
#
# La plupart de ces techniques sont univariées, ce qui signifie qu'elles évaluent chaque prédicteur de manière isolée.
# de manière isolée. Dans ce cas, l'existence de prédicteurs corrélés permet de sélectionner des prédicteurs importants, mais redondants. Les conséquences évidentes de ce problème sont que trop de prédicteurs sont choisis et, par conséquent, des problèmes de colinéarité apparaissent.
#
# Nous pouvons considérer un arbre de types de variables d'entrée et de sortie et sélectionner des mesures statistiques de relation ou de corrélation conçues pour fonctionner avec ces variables.
# relation ou de corrélation conçues pour fonctionner avec ces types de données.
#
# La figure ci-dessous résume cet arbre et certaines statistiques couramment suggérées à utiliser aux feuilles de l'arbre.
#
# Figure 11.1 : Comment choisir les méthodes de sélection des caractéristiques pour l'apprentissage automatique.
# Dans ce cadre, passons en revue quelques mesures statistiques univariées pouvant être utilisées pour la sélection de caractéristiques basée sur des filtres.
#
#
# ***III.3) Statistiques pour la sélection de caractéristiques***
#
# ***III.3.1 Entrée numérique, sortie numérique***
#
# Il s'agit d'un problème de modélisation prédictive par régression avec des variables d'entrée numériques.
#
# Les techniques les plus courantes consistent à utiliser un coefficient de corrélation, tel que celui de Pearson pour une corrélation linéaire,
# ou des méthodes basées sur les rangs pour une corrélation non linéaire.
# Coefficient de corrélation de Pearson (linéaire).
# Coefficient de rang de Spearman (non linéaire).
#
# **Information mutuelle.**
#
# Nous étudierons la sélection de caractéristiques avec des variables d'entrée numériques et des variables de sortie numériques (régression) au chapitre 14 en utilisant la corrélation de Pearson et l'information mutuelle. En fait, l'information mutuelle
# mutuelle est une méthode puissante qui peut s'avérer utile pour les données catégorielles et numériques.
# numériques.
#
# **III.2)Entrée numérique, sortie catégorielle**
#
# Il s'agit d'un problème de modélisation prédictive de classification avec des variables d'entrée numériques.
#
# Il s'agit peut-être de l'exemple le plus courant de problème de classification sont basées sur la corrélation, bien que dans ce cas, elles doivent prendre en compte la cible catégorielle.
#
# + Coefficient de corrélation ANOVA (linéaire).
#
# + Coefficient de rang de Kendall (non linéaire).
# Information mutuelle.
#
# **Le coefficient de Kendall suppose que la variable catégorielle est ordinale. Nous allons explorer la sélection de caractéristiques
# avec des variables d'entrée numériques et des variables de sortie catégoriques (classification) au chapitre 13 en utilisant l'ANOVA et l'information mutuelle.**
#
#
# **III.3) Entrée catégorielle, sortie numérique***
#
# **Il s'agit d'un problème de modélisation prédictive par régression avec des variables d'entrée catégorielles. Il s'agit d'un
# exemple étrange de problème de régression (par exemple, vous ne le rencontrerez pas souvent). Néanmoins, vous pouvez utiliser les mêmes méthodes d'entrée numérique et de sortie catégorielle (décrites ci-dessus), mais en sens inverse.**
#
#
#
# **III) Entrée catégorielle, sortie catégorielle**
#
# ***Il s'agit d'un problème de modélisation prédictive de classification avec des variables d'entrée catégorielles.
# La mesure de corrélation la plus courante pour les données catégorielles est le test du chi carré. Vous pouvez également utiliser
# l'information mutuelle (gain d'information) du domaine de la théorie de l'information.***
#
# **Test du chi carré (tableaux de contingence). Information mutuelle.**
#
# + Nous explorerons la sélection de caractéristiques avec des variables d'entrée et de sortie catégoriques (classification)
#
# + au chapitre 12 en utilisant le Khi-deux et l'information mutuelle.
#
# **11.4 Sélection de caractéristiques avec tout type de données**
#
# + Jusqu'à présent, nous avons étudié les mesures de corrélation statistique spécifiques aux types de données numériques et catégoriques.
#
# + Il est rare que nous ayons un ensemble de données avec un seul type de données de variable d'entrée.
#
# + L'une des approches permettant de gérer différents types de données de variables d'entrée consiste à sélectionner séparément les variables d'entrée numériques et les variables catégorielles à l'aide de métriques appropriées.
#
#
# + Ceci peut être réalisé à l'aide de la classe **ColumnTransformer** qui sera présentée au chapitre 24.
#
# + Une autre approche consiste à utiliser une méthode enveloppante qui effectue une recherche parmi différentes combinaisons ou sous-ensembles de caractéristiques d'entrée sur la base des critères suivants
# combinaisons ou sous-ensembles de caractéristiques d'entrée en fonction de leur effet sur la qualité du modèle.
#
#
# + **Les méthodes simples** peuvent créer un arbre de toutes les combinaisons possibles de caractéristiques d'entrée et naviguer dans le graphe en fonction du gain, par exemple en utilisant un algorithme de recherche d'arbre de type best-first.
#
#
# + Alternativement, **un algorithme de recherche globale stochastique** peut être utilisé, tel qu'un algorithme génétique ou un recuit simulé.
#
# + Bien qu'efficaces, ces approches peuvent être très coûteuses en termes de calcul, en particulier pour les grands ensembles de données d'apprentissage et les modèles sophistiqués.
#
#
# + Méthodes de recherche dans les arbres (recherche en profondeur, recherche en largeur, etc.).
#
# + Recherche globale stochastique (recuit simulé, algorithme génétique).
#
# + Les méthodes plus simples consistent à ajouter ou à supprimer systématiquement des caractéristiques du modèle jusqu'à ce qu'aucune amélioration ne soit constatée.
#
# + Il s'agit notamment des modèles dits "step-wise" (par exemple, la régression step-wise) et RFE. Nous examinerons de plus près la RFE au chapitre 15).
#
# + Une dernière méthode agnostique de type de données consiste à noter les caractéristiques d'entrée à l'aide d'un modèle et à utiliser une méthode de sélection des caractéristiques basée sur un filtre.
#
# + De nombreux modèles sélectionnent ou notent automatiquement les
# caractéristiques dans le cadre de l'ajustement du modèle et ces scores peuvent être utilisés comme les méthodes statistiques décrites ci-dessus.
#
# + Les algorithmes d'arbres de décision et les ensembles d'algorithmes d'arbres de décision fournissent une méthode de sélection des caractéristiques basée sur un filtre.
#
# + une méthode de notation des variables d'entrée qui ne tient pas compte du type de données.comme :
#
# + Les arbres de classification et de régression (CART).
# + Forêt aléatoire
# + Arbres de décision en sac
# + Boosting de gradient
# + Nous explorerons plus en détail les méthodes d'importance des caractéristiques au Chapitre 16.
#
#
# **11.5 Questions courantes**
#
# Cette section énumère quelques questions et réponses courantes lors de la sélection de caractéristiques.
#
# **11.6. Lectures complémentaires**
#
# **Q. Comment filtrer les variables d'entrée ?**
#
# Il existe deux techniques principales pour filtrer les variables d'entrée.
#
# + La première consiste à classer toutes les variables d'entrée
# par leur score et à sélectionner les k premières variables d'entrée ayant le score le plus élevé.
#
# + La deuxième approche consiste à convertir les scores en pourcentage du score le plus élevé et à sélectionner toutes les caractéristiques supérieures à un percentile minimum.
#
# Ces deux approches sont disponibles dans la bibliothèque scikit-learn :
#
# + Sélectionner les k meilleures variables : **SelectKBest.**
#
# + Sélectionner les variables du percentile supérieur : **SelectPercentile.**
#
#
# **Q. Comment puis-je utiliser les statistiques pour d'autres types de données ?**
#
# Pensez à transformer les variables afin d'accéder à différentes méthodes statistiques. Par exemple vous pouvez transformer une variable catégorielle en variable ordinale, même si elle ne l'est pas, et voir si des résultats intéressants en ressortent (voir le chapitre 19).
# résultats intéressants (voir le chapitre 19). Vous pouvez également transformer une variable numérique en variable discrète pour essayer
# mesures catégorielles (voir le chapitre 22).
# Certaines mesures statistiques supposent des propriétés des variables, comme la **corrélation de Pearson** qui suppose une distribution de probabilité gaussienne pour les observations et une relation linéaire.
# Vous pouvez transformer les données pour qu'elles répondent aux attentes du test et essayer le test sans tenir compte des attentes et comparer les résultats (voir le chapitre 22).
# les attentes et comparer les résultats (voir chapitre 20 et chapitre 21.
#
#
# **Q. Comment puis-je savoir quelles caractéristiques ont été sélectionnées ?**
#
# *Vous pouvez appliquer une méthode de sélection des caractéristiques dans le cadre du pipeline de modélisation.
# Si vous voulez savoir quelles caractéristiques ont été sélectionnées
# par une méthode de sélection de caractéristiques donnée, vous pouvez appliquer la méthode de sélection de caractéristiques directement à l'ensemble de vos données d'apprentissage et produire un rapport sur les caractéristiques sélectionnées.
# Vous pouvez ensuite relier les index de colonnes aux noms de vos variables d'entrée pour vous aider à interpréter votre ensemble de données.*
#
#
# **Q. Quelle est la meilleure méthode de sélection des caractéristiques ?**
#
# *C'est impossible à savoir. Tout comme il n'y a pas de meilleur algorithme d'apprentissage automatique, il n'y a pas de meilleure technique de sélection de caractéristiques.
# Du moins, pas de manière universelle. Au lieu de cela, vous devez découvrir ce qui fonctionne pour votre problème spécifique en utilisant une expérimentation systématique et minutieuse. Essayez une serie de
# techniques et découvrez ce qui fonctionne le mieux pour votre problème spécifique.*
#
# + **Representation graphique des choix approprié**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Chapitre 12: Comment sélectionner les données catégorielles**
#
# **Caractéristiques**
#
# + **La sélection des caractéristique** est le processus d'identification et de sélection d'un sous-ensemble de caractéristiques d'entrée qui sont les plus pertinentes pour la variable cible.
#
# + La sélection des caractéristiques est souvent simple lorsqu'on travaille avec des données à valeurs réelles, par exemple en utilisant le coefficient de **corrélation de Pearson.**
#
# + lorsqu'il s'agit de **données catégorielles**. Les deux méthodes de sélection de caractéristiques les plus couramment utilisées pour
# données d'entrée catégoriques lorsque la variable cible est également catégorique (par exemple, la modélisation prédictive de la classification) sont **le chi carré et la statistique de l'information mutuelle.**
#
# + Dans ce tutoriel, vous découvrirez comment effectuer une sélection de caractéristiques avec des données d'entrée catégoriques.
#
# + Après avoir terminé ce tutoriel, vous saurez :
#
# + Le problème de modélisation prédictive du cancer du sein avec des entrées catégorielles et une variable cible de classification binaire.
#
# + Comment évaluer l'importance des caractéristiques catégorielles en utilisant les statistiques du chi carré et de l'information mutuelle.
#
# + Comment effectuer une sélection de caractéristiques pour les données catégorielles lors de l'ajustement et de l'évaluation d'un modèle de classification.
#
#
# Commençons.
#
# **12.1 Présentation du tutoriel**
#
# Ce tutoriel est divisé en trois parties, à savoir :
#
# **1.** Ensemble de données catégoriques sur le cancer du sein
#
# **2.** Sélection des caractéristiques catégorielles
#
# **3.** Modélisation avec les caractéristiques sélectionnées
#
# **2.2 Jeu de données catégoriques sur le cancer du sein**
#
# + Pour ce tutoriel, nous utiliserons l'ensemble de données sur le cancer du sein, qui a été largement étudié en tant que jeu de données d'apprentissage automatique depuis les années 1980.
#
# + Ce jeu de données classe les données des patientes atteintes d'un cancer du sein comme étant soit une récidive, soit une absence de récidive du cancer.
#
# + Il y a 286 exemples et 9 variables d'entrée.
#
# + Il s'agit d'un problème de classification binaire.
#
# + Un modèle naïf peut atteindre une précision de 70 % sur cet ensemble de données. Un bon score est d'environ 76 pour cent.
#
# + Nous viserons cette régionmais notez que les modèles de ce tutoriel ne sont pas optimisés ; ils sont conçus pour démontrer les schémas d'encodage.
#
# + Vous pouvez en savoir plus sur le jeu de données ici :
#
# ***Breast Cancer Dataset (breast-cancer.csv).***
#
# ***Description du jeu de données sur le cancer du sein (breast-cancer.names).***
#
# 1) https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv
#
# 2) https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.names
#
# + En examinant les données, nous pouvons constater que les neuf variables d'entrée sont catégoriques.
#
# + Plus précisément, toutes les variables sont des chaînes de caractères entre guillemets ; certaines sont ordinales et d'autres ne le sont pas.

# %%
# example of loading and preparing the breast cancer dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# load the dataset
def load_dataset(filename):

  # load the dataset
  data = read_csv(filename, header=None)

  # retrieve array
  dataset = data.values

  # split into input and output variables
  X = dataset[:, :-1]
  y = dataset[:,-1]

  # format all fields as string
  X = X.astype(str)
  return X, y

# prepare input data
def prepare_inputs(X_train, X_test):
  oe = OrdinalEncoder()
  oe.fit(X_train)
  X_train_enc = oe.transform(X_train)
  X_test_enc = oe.transform(X_test)
  return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
  le = LabelEncoder()
  le.fit(y_train)
  y_train_enc = le.transform(y_train)
  y_test_enc = le.transform(y_test)
  return y_train_enc, y_test_enc

# load the dataset
filename= 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# summarize
print('Train', X_train_enc.shape, y_train_enc.shape)
print('Test', X_test_enc.shape, y_test_enc.shape)
# Out:
# Train (191, 9) (191,)
# Test (95, 9) (95,)

# %% [markdown]
# **12.3 Sélection de caractéristiques catégorielles**
#
# + Il existe deux techniques populaires de sélection de caractéristiques qui peuvent être utilisées pour des données d'entrée catégoriques et une variable cible catégorique (classe).
#
# + Il s'agit de:
#   + La statistique du Khi-deux.
#   + La statistique de l'information mutuelle.
#
# Examinons chacune d'entre elles de plus près.
#
# **12.3.1 Sélection des caractéristiques du chi carré**
#
# + ***Le chi carré de Pearson (lettre grecque au carré, par exemple χ²
# prononcé kai) est un exemple de test d'indépendance entre des variables catégorielles.***
#
# + Les résultats de ce test peuvent être utilisés pour la sélection des caractéristiques, où les caractéristiques qui sont indépendantes de la
# variable cible peuvent être supprimées de l'ensemble de données.
#
# + Lorsqu'il y a trois niveaux ou plus pour le prédicteur, le degré d'association entre le prédicteur et le résultat peut être mesuré à l'aide de statistiques telles que le χ²
#
#
# + La bibliothèque machine scikit-learn fournit une implémentation du test du chi carré dans la **fonction chi2()**.
#
# + Cette fonction peut être utilisée dans une stratégie de sélection de caractéristiques, telle que la sélection des k caractéristiques les plus pertinentes (valeurs les plus grandes) via la classe **SelectKBest.**
#
# + Par exemple, nous pouvons définir la classe **SelectKBest** pour utiliser la fonction chi2() et sélectionner toutes les caractéristiques, puis transformer les ensembles de formation et de test.
#
#
#
#
# **Datasets:**
#
# 1) https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv
#
# 2) https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.names

# %%
# example of chi squared feature selection for categorical data
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from matplotlib import pyplot

# load the dataset
def load_dataset(filename):

  # load the dataset
  data = read_csv(filename, header=None)

  # retrieve array
  dataset = data.values

  # split into input and output variables
  X = dataset[:, :-1]
  y = dataset[:,-1]

  # format all fields as string
  X = X.astype(str)
  return X, y

# prepare input data
def prepare_inputs(X_train, X_test):
  oe = OrdinalEncoder()
  oe.fit(X_train)
  X_train_enc = oe.transform(X_train)
  X_test_enc = oe.transform(X_test)
  return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
  le = LabelEncoder()
  le.fit(y_train)
  y_train_enc = le.transform(y_train)
  y_test_enc = le.transform(y_test)
  return y_train_enc, y_test_enc

# feature selection
def select_features(X_train, y_train, X_test):
  fs = SelectKBest(score_func=chi2, k='all')
  fs.fit(X_train, y_train)
  X_train_fs = fs.transform(X_train)
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs

# load the dataset
filename= 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train_enc, y_train_enc, X_test_enc)


# what are scores for the features
for i in range(len(fs.scores_)):
  print('Feature %d: %f' % (i, fs.scores_[i]))

# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature 0: 0.472553
# Feature 1: 0.029193
# Feature 2: 2.137658
# Feature 3: 29.381059
# Feature 4: 8.222601
# Feature 5: 8.100183
# Feature 6: 1.273822
# Feature 7: 0.950682
# Feature 8: 3.699989

# %% [markdown]
# **12.3.2 Sélection de caractéristiques d'information mutuelle**
#
# + **L'information mutuelle, issue du domaine de la théorie de l'information, est l'application du gain d'information (généralement utilisé dans la construction d'un système de décision) à la sélection de caractéristiques.**
#
# + **L'information mutuelle** est calculée entre deux variables et mesure la réduction de l'incertitude pour une variable
# étant donné une valeur connue de l'autre variable.
#
# + La bibliothèque d'apprentissage automatique scikit-learn fournit
# une implémentation de l'information mutuelle pour la sélection de caractéristiques via la fonction info mutuelle **classif().**
#
# + Comme chi2(), elle peut être utilisée dans la stratégie de sélection de caractéristiques **SelectKBest** (et d'autres stratégies).

# %%
# example of mutual information feature selection for categorical data
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from matplotlib import pyplot

# load the dataset
def load_dataset(filename):

  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)

  # retrieve numpy array
  dataset = data.values

  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]

  # format all fields as string
  X = X.astype(str)
  return X, y

# prepare input data
def prepare_inputs(X_train, X_test):
  oe = OrdinalEncoder()
  oe.fit(X_train)
  X_train_enc = oe.transform(X_train)
  X_test_enc = oe.transform(X_test)
  return X_train_enc, X_test_enc


# prepare target
def prepare_targets(y_train, y_test):
  le = LabelEncoder()
  le.fit(y_train)
  y_train_enc = le.transform(y_train)
  y_test_enc = le.transform(y_test)
  return y_train_enc, y_test_enc

# feature selection
def select_features(X_train, y_train, X_test):
  fs = SelectKBest(score_func=mutual_info_classif, k='all')
  fs.fit(X_train, y_train)
  X_train_fs = fs.transform(X_train)
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs


# load the dataset
filename= 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train_enc, y_train_enc, X_test_enc)

# what are scores for the features
for i in range(len(fs.scores_)):
  print('Feature %d: %f' % (i, fs.scores_[i]))


# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature 0: 0.028796
# Feature 1: 0.002007
# Feature 2: 0.047534
# Feature 3: 0.000000
# Feature 4: 0.000000
# Feature 5: 0.016912
# Feature 6: 0.000000
# Feature 7: 0.039259
# Feature 8: 0.008833

# %% [markdown]
# **12.4 Modélisation avec des caractéristiques sélectionnées**
#
# + Il existe de nombreuses techniques différentes pour noter les caractéristiques et sélectionner les caractéristiques en fonction des scores ;
#
# + Comment savoir laquelle utiliser ?
#
# + Une approche robuste consiste à évaluer des modèles utilisant différentes méthodes de sélection de caractéristiques (et nombres de caractéristiques) et de sélectionner la méthode qui aboutit au
# modèle présentant les meilleures performances.
#
# + Dans cette section, nous allons évaluer un modèle de régression logistique avec toutes les caractéristiques, comparé à un modèle construit à partir des **caractéristiques sélectionnées par le chi carré** et les **caractéristiques sélectionnées par l'information mutuelle.**
#
# + **La régression logistique** est un bon modèle pour tester les méthodes de sélection des caractéristiques, car il peut être plus performant si les caractéristiques non pertinentes sont supprimées du modèle.
#
# **12.4.1 Modèle construit en utilisant toutes les caractéristiques**
#
# + Dans un premier temps, nous allons évaluer un modèle de régression logistique en utilisant toutes les caractéristiques disponibles.
#
# + Le modèle est ajusté sur l'ensemble de données d'entraînement et évalué sur l'ensemble de données de test. L'exemple complet est présenté ci-dessous.

# %%
# example of loading and preparing the breast cancer dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score


# load the dataset
def load_dataset(filename):

  # load the dataset
  data = read_csv(filename, header=None)

  # retrieve array
  dataset = data.values

  # split into input and output variables
  X = dataset[:, :-1]
  y = dataset[:,-1]

  # format all fields as string
  X = X.astype(str)
  return X, y

# prepare input data
def prepare_inputs(X_train, X_test):
  oe = OrdinalEncoder()
  oe.fit(X_train)
  X_train_enc = oe.transform(X_train)
  X_test_enc = oe.transform(X_test)
  return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
  le = LabelEncoder()
  le.fit(y_train)
  y_train_enc = le.transform(y_train)
  y_test_enc = le.transform(y_test)
  return y_train_enc, y_test_enc

# load the dataset
filename= 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)

# fit the model
model = LogisticRegression(solver='lbfgs')
model.fit(X_train_fs, y_train_enc)
# evaluate the model
yhat = model.predict(X_test_fs)
# evaluate predictions
accuracy = accuracy_score(y_test_enc, yhat)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 75.79

# %% [markdown]
# **12.4.2 Model Built Using Chi-Squared Features**

# %%
# evaluation of a model fit using chi squared input features
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  # format all fields as string
  X = X.astype(str)
  return X, y


# prepare input data
def prepare_inputs(X_train, X_test):
  oe = OrdinalEncoder()
  oe.fit(X_train)
  X_train_enc = oe.transform(X_train)
  X_test_enc = oe.transform(X_test)
  return X_train_enc, X_test_enc
  # prepare target


def prepare_targets(y_train, y_test):
  le = LabelEncoder()
  le.fit(y_train)
  y_train_enc = le.transform(y_train)
  y_test_enc = le.transform(y_test)
  return y_train_enc, y_test_enc

# feature selection
def select_features(X_train, y_train, X_test):
  fs = SelectKBest(score_func=chi2, k=4)
  fs.fit(X_train, y_train)
  X_train_fs = fs.transform(X_train)
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs

# load the dataset
filename= 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# feature selection
X_train_fs, X_test_fs = select_features(X_train_enc, y_train_enc, X_test_enc)


# fit the model
model = LogisticRegression(solver='lbfgs')
model.fit(X_train_fs, y_train_enc)
# evaluate the model
yhat = model.predict(X_test_fs)
# evaluate predictions
accuracy = accuracy_score(y_test_enc, yhat)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 74.74

# %% [markdown]
# **12.4.3 Model Built Using Mutual Information Features**

# %%
# evaluation of a model fit using mutual information input features
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  # format all fields as string
  X = X.astype(str)
  return X, y


# prepare input data
def prepare_inputs(X_train, X_test):
  oe = OrdinalEncoder()
  oe.fit(X_train)
  X_train_enc = oe.transform(X_train)
  X_test_enc = oe.transform(X_test)
  return X_train_enc, X_test_enc



# prepare target
def prepare_targets(y_train, y_test):
  le = LabelEncoder()
  le.fit(y_train)
  y_train_enc = le.transform(y_train)
  y_test_enc = le.transform(y_test)
  return y_train_enc, y_test_enc

# feature selection
def select_features(X_train, y_train, X_test):
  fs = SelectKBest(score_func=mutual_info_classif, k=4)
  fs.fit(X_train, y_train)
  X_train_fs = fs.transform(X_train)
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs

# load the dataset
filename= 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# feature selection
X_train_fs, X_test_fs = select_features(X_train_enc, y_train_enc, X_test_enc)


# fit the model
model = LogisticRegression(solver='lbfgs')
model.fit(X_train_fs, y_train_enc)
# evaluate the model
yhat = model.predict(X_test_fs)
# evaluate predictions
accuracy = accuracy_score(y_test_enc, yhat)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 68.42

# %% [markdown]
# **Chapitre 13: Comment sélectionner l'entrée numérique**
#
# **Caractéristiques**
#
# + **La sélection des caractéristiques** est le processus d'identification et de sélection d'un sous-ensemble de caractéristiques d'entrée qui sont les plus pertinentes pour la variable cible.
#
# + La sélection des caractéristiques est souvent simple lorsqu'on travaille avec des données d'entrée et de sortie à valeurs réelles, par exemple en utilisant le **coefficient de corrélation de Pearson**
# mais peut s'avérer difficile lorsque l'on travaille avec des données **d'entrée numériques et une variable cible catégorique**.
#
# Les deux méthodes de sélection de caractéristiques les plus couramment utilisées pour les données d'entrée numériques lorsque la variable cible est catégorique (p. ex. lorsque **la variable cible est catégorique** (par exemple, **la modélisation prédictive de la classification**) sont la statistique du test **F de l'ANOVA** et la
# et **la statistique d'information mutuelle**.
#
# + Dans ce tutoriel, vous découvrirez comment effectuer une
# sélection de caractéristiques avec des données d'entrée numériques pour la classification.
#
# Après avoir terminé ce tutoriel, vous connaîtrez :
#
# + Le problème de modélisation prédictive du diabète avec des entrées numériques et une classification binaire
#
# les variables cibles.
#
# + Comment évaluer l'importance des caractéristiques numériques à l'aide du **test F de l'ANOVA** et des **statistiques d'information mutuelle**.
#
# + Comment effectuer une sélection de caractéristiques pour les données numériques lors de l'ajustement et de l'évaluation d'un modèle de classification.
#
# Commençons.
#
# **13.1 Présentation du tutoriel**
#
# Ce tutoriel est divisé en quatre parties :
#
# ***1. Ensemble de données numériques sur le diabète***
#
# ***2. Sélection des caractéristiques numériques***
#
# ***3. Modélisation avec les caractéristiques sélectionnées***
#
# ***4. Ajuster le nombre de caractéristiques sélectionnées***

# %% [markdown]
# ***13.2 Diabetes Numerical Dataset***
#
# * https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv
#
# * https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.names

# %%
# load and summarize the dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)

  # retrieve numpy array
  dataset = data.values

  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  return X, y

# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# summarize
print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (514, 8) (514,)
# Test (254, 8) (254,)

# %% [markdown]
# **13.3 Sélection de caractéristiques numériques**
#
#
# *Il existe deux techniques populaires de sélection de caractéristiques qui peuvent être utilisées pour des données d'entrée numériques
# et une variable cible catégorique (classe).*
#
# *Il s'agit de:*
#
# + La statistique F de l'ANOVA.
# + La statistique d'information mutuelle.
#
# Examinons chacune d'entre elles de plus près.
#
# **13.3.1 Sélection des caractéristiques du test F de l'ANOVA**
#
# + **ANOVA est l'acronyme de l'analyse de la variance**.
#
# + Il s'agit d'un test d'hypothèse statistique paramétrique permettant de déterminer si les moyennes de deux échantillons de données ou plus (souvent trois ou plus) proviennent ou non de la même distribution.
#
# + Une statistique F, ou test F, est une classe de tests statistiques qui
# calculent le rapport entre les valeurs de variance, telles que la variance de deux échantillons différents ou la variance expliquée et inexpliquée par un test statistique, comme l'ANOVA.
#
# + La méthode ANOVA est un type de statistique F appelé ici test F d'ANOVA.
#
# + Il est important de noter que l'ANOVA est utilisée lorsqu'une **variable est numérique** et **l'autre catégorique**, comme par exemple
# des **variables d'entrée numériques et une variable cible de classification** dans une **tâche de classification**.
#
# + Les résultats de ce test peuvent être utilisés pour la sélection des caractéristiques, où les caractéristiques qui sont indépendantes de la variable cible peuvent être retirées des données.
#
#
# + Lorsque le résultat est numérique, et que [...] le prédicteur a plus de deux niveaux, la statistique F de l'ANOVA traditionnelle ne peut être utilisée.
#
# + la statistique F traditionnelle de l'ANOVA peut être calculée.
#
# + La bibliothèque machine scikit-learn fournit une mise en œuvre du test F ANOVA dans la fonction f classif().
#
# + Cette fonction peut être utilisée dans une stratégie de sélection de caractéristiques, par exemple pour sélectionner les k caractéristiques les plus pertinentes (valeurs les plus grandes) via la classe **SelectKBest**.
#
#
# + Par exemple, nous pouvons définir la classe **SelectKBest** pour utiliser la fonction **f classif()** et sélectionner toutes les caractéristiques, puis transformer les ensembles de formation et de test.

# %%
# example of anova f-test feature selection for numerical data
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from matplotlib import pyplot

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  return X, y

# feature selection
def select_features(X_train, y_train, X_test):
  # configure to select all features
  fs = SelectKBest(score_func=f_classif, k='all')
  # learn relationship from training data
  fs.fit(X_train, y_train)
  # transform train input data
  X_train_fs = fs.transform(X_train)
  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs

# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# what are scores for the features
for i in range(len(fs.scores_)):
  print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature 0: 16.527385
# Feature 1: 131.325562
# Feature 2: 0.042371
# Feature 3: 1.415216
# Feature 4: 12.778966
# Feature 5: 49.209523
# Feature 6: 13.377142
# Feature 7: 25.126440

# %% [markdown]
# **13.3.2 Sélection des caractéristiques de l'information mutuelle**
#
# + **L'information mutuelle**, issue de la théorie de l'information, est l'application du gain d'information (généralement utilisé dans la construction d'arbres de décision) à la sélection de caractéristiques.
#
# + **L'information mutuelle** est calculée entre deux variables et mesure la réduction de l'incertitude pour une variable en fonction d'une valeur connue de l'autre variable.
#
# + L'information mutuelle est simple lorsqu'on considère la distribution de deux variables discrètes (catégoriques ou ordinales), telles que des données d'entrée et de sortie catégoriques.
#
# + Néanmoins, elle peut être adaptée pour être utilisée avec des entrées numériques et des sorties catégoriques.
#
# + Pour des détails techniques sur la façon dont cela peut être réalisé, voir l'article de 2014 intitulé Mutual Information entre les ensembles de données discrètes et continues.
#
# + La bibliothèque d'apprentissage automatique scikit-learn fournit
# une implémentation de l'information mutuelle pour la sélection de caractéristiques avec des variables d'entrée variables de sortie catégorielles via la fonction **info mutuelle classif()**. Comme la fonction **f classif()**, elle peut être utilisée
# dans la stratégie de sélection de caractéristiques **SelectKBest** (et d'autres stratégies).
#
# **13.3.2 Sélection des caractéristiques de l'information mutuelle**

# %%
#example of mutual information feature selection for numerical input data
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from matplotlib import pyplot

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  return X, y

# feature selection
def select_features(X_train, y_train, X_test):
  # configure to select all features
  fs = SelectKBest(score_func=mutual_info_classif, k='all')
  # learn relationship from training data
  fs.fit(X_train, y_train)
  # transform train input data
  X_train_fs = fs.transform(X_train)
  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs

# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv'
X, y = load_dataset(filename)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
# what are scores for the features
for i in range(len(fs.scores_)):
  print('Feature %d: %f' % (i, fs.scores_[i]))

# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature 0: 0.049604
# Feature 1: 0.117688
# Feature 2: 0.035348
# Feature 3: 0.013475
# Feature 4: 0.040032
# Feature 5: 0.077351
# Feature 6: 0.010416
# Feature 7: 0.059296

# %% [markdown]
# **13.4.2 Model Built Using ANOVA F-test Features**

# %%
# evaluation of a model using 4 features chosen with anova f-test
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  return X, y

# feature selection
def select_features(X_train, y_train, X_test):
  # configure to select a subset of features
  fs = SelectKBest(score_func=f_classif, k=4)
  # learn relationship from training data
  fs.fit(X_train, y_train)
  # transform train input data
  X_train_fs = fs.transform(X_train)
  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs


# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv'
X, y = load_dataset(filename)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# fit the model
model = LogisticRegression(solver='liblinear')
model.fit(X_train_fs, y_train)

# evaluate the model
yhat = model.predict(X_test_fs)

# evaluate predictions
accuracy = accuracy_score(y_test, yhat)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 78.74

# %% [markdown]
# **13.4.3 Model Built Using Mutual Information Features**

# %%
# evaluation of a model using 4 features chosen with mutual information
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  return X, y

# feature selection
def select_features(X_train, y_train, X_test):
  # configure to select a subset of features
  fs = SelectKBest(score_func=mutual_info_classif, k=4)
  # learn relationship from training data
  fs.fit(X_train, y_train)
  # transform train input data
  X_train_fs = fs.transform(X_train)
  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs


# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv'
X, y = load_dataset(filename)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# fit the model
model = LogisticRegression(solver='liblinear')
model.fit(X_train_fs, y_train)

# evaluate the model
yhat = model.predict(X_test_fs)

# evaluate predictions
accuracy = accuracy_score(y_test, yhat)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 77.95

# %% [markdown]
# **13.5 Tune the Number of Selected Features**

# %%
# compare different numbers of features selected using anova f-test
from pandas import read_csv
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  return X, y

# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv'
X, y = load_dataset(filename)

# define the evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# define the pipeline to evaluate
model = LogisticRegression(solver='liblinear')
fs = SelectKBest(score_func=f_classif)
pipeline = Pipeline(steps=[('anova',fs), ('lr', model)])

# define the grid
grid = dict()
grid['anova__k'] = [i+1 for i in range(X.shape[1])]

# define the grid search
search = GridSearchCV(pipeline, grid, scoring='accuracy', n_jobs=-1, cv=cv)

# perform the search
results = search.fit(X, y)

# summarize best
print('Best Mean Accuracy: %.3f' % results.best_score_)
print('Best Config: %s' % results.best_params_)
# Out:
# Best Mean Accuracy: 0.770
# Best Config: {'anova__k': 5}

# %%
# compare different numbers of features selected using anova f-test
from numpy import mean
from numpy import std
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# load the dataset
def load_dataset(filename):
  # load the dataset as a pandas DataFrame
  data = read_csv(filename, header=None)
  # retrieve numpy array
  dataset = data.values
  # split into input (X) and output (y) variables
  X = dataset[:, :-1]
  y = dataset[:,-1]
  return X, y

# evaluate a given model using cross-validation
def evaluate_model(model):
  cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
  return scores


# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv'
X, y = load_dataset(filename)
# define number of features to evaluate
num_features = [i+1 for i in range(X.shape[1])]
# enumerate each number of features
results = list()
for k in num_features:
  # create pipeline
  model = LogisticRegression(solver='liblinear')
  fs = SelectKBest(score_func=f_classif, k=k)
  pipeline = Pipeline(steps=[('anova',fs), ('lr', model)])
  # evaluate the model
  scores = evaluate_model(pipeline)
  results.append(scores)
  # summarize the results
  print('>%d %.3f (%.3f)' % (k, mean(scores), std(scores)))

# plot model performance for comparison
pyplot.boxplot(results, labels=num_features, showmeans=True)
pyplot.show()
# Out:
# >1 0.748 (0.048)
# >2 0.756 (0.042)
# >3 0.761 (0.044)
# >4 0.759 (0.042)
# >5 0.770 (0.041)
# >6 0.766 (0.042)
# >7 0.770 (0.042)
# >8 0.768 (0.040)

# %% [markdown]
# **Chapitre 14: Comment sélectionner les caractéristiques de la numérique**
#
# + **La sélection de caractéristiques** est le processus d'identification et de sélection d'un sous-ensemble de variables d'entrée qui sont les plus pertinentes pour la variable cible.
#
# + Le cas le plus simple de sélection de caractéristiques est peut-être celui où il y a des variables d'entrée numériques et une cible numérique pour la régression.
#
# + le cas où il existe des variables d'entrée numériques et une cible numérique pour la modélisation prédictive par régression.
#
# + En effet, la force de la relation entre chaque variable d'entrée et la cible peut être calculée, appelée corrélation, et comparée l'une à l'autre.
#
# + Dans ce tutoriel, vous découvrirez comment effectuer une sélection de caractéristiques avec des données d'entrée numériques pour la modélisation prédictive par régression.
#
# **Après avoir terminé ce tutoriel, vous saurez** :
#
# + Comment évaluer l'importance des données d'entrée numériques en utilisant les statistiques de corrélation et d'information mutuelle.
#
# + Comment effectuer une sélection de caractéristiques pour les données d'entrée numériques lors de l'ajustement et de l'évaluation d'un modèle de régression.
#
# + Comment régler le nombre de caractéristiques sélectionnées dans un pipeline de modélisation en utilisant une recherche par grille.
# Commençons.
#
# **14.1 Présentation du tutoriel**
#
# Ce tutoriel est divisé en quatre parties :
#
# **1. Jeu de données de régression**
#
# **2. Sélection numérique des caractéristiques**
#
# **3. Modélisation avec les caractéristiques sélectionnées**
#
# **4. Ajuster le nombre de caractéristiques sélectionnées**

# %% [markdown]
# **14.2 Jeu de données de régression**
#
# + Nous allons utiliser un jeu de données de régression synthétique comme base de ce tutoriel.
#
# + Rappelons qu'un problème de régression est un problème dans lequel nous voulons prédire une valeur numérique.
#
# + Dans ce cas, nous avons besoin d'un ensemble de données qui a également des variables d'entrée numériques.
#
# + La fonction **make_regression()** de la bibliothèque scikit-learn peut être utilisée pour définir un ensemble de données.
#
# + Elle permet de contrôler le nombre d'échantillons, le nombre de caractéristiques d'entrée et, surtout, le nombre de caractéristiques d'entrée pertinentes et non pertinentes.
#
# + Ce point est essentiel car nous souhaitons spécifiquement un ensemble de données dont nous savons qu'il comporte des caractéristiques d'entrée non pertinentes.
#
# + Dans ce cas, nous définirons un ensemble de données avec 1 000 échantillons, chacun avec 100 caractéristiques d'entrée, dont 10 sont informatives et 10 autres non pertinentes.

# %%
# load and summarize the dataset
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
# generate regression dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1,
random_state=1)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# summarize
print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (670, 100) (670,)
# Test (330, 100) (330,)

# %% [markdown]
# **14.3 Sélection numérique des caractéristiques**
#
# + Il existe deux techniques populaires de sélection de caractéristiques qui peuvent être utilisées pour des données d'entrée numériques.
#
# + Il s'agit des techniques suivantes:
#   + Les statistiques de corrélation.
#   + Les statistiques d'information mutuelle.
#
# Examinons chacune d'entre elles de plus près.
#
# **14.3.1 Sélection des caractéristiques de corrélation**
#
# + **La corrélation** est une mesure de l'évolution conjointe de deux variables.
#
# + **La mesure de corrélation** la plus courante est sans doute la **corrélation de Pearson**, qui suppose une distribution gaussienne pour chaque variable et rend compte de leur relation linéaire.
#
# + Pour les prédicteurs numériques, l'approche classique pour quantifier chaque relation avec le résultat utilise la statistique de corrélation d'échantillon.
#
# + le résultat utilise la statistique de corrélation d'échantillon.
#
# + Les scores de corrélation linéaire ont généralement une valeur comprise entre -1 et 1, 0 représentant l'absence de relation.
#
# + Pour la sélection des caractéristiques, les scores sont positifs et nous sommes souvent intéressés par un score positif.
#
# + plus la valeur positive est grande, plus la relation est importante et plus il est probable que la caractéristique soit sélectionnée pour la modélisation,
#
# + Ainsi, la corrélation linéaire peut être convertie en une statistique de corrélation avec uniquement des valeurs positives.
#
# + La bibliothèque machine scikit-learn fournit une implémentation de la statistique de corrélation dans la fonction la fonction **f_regression()**.
#
# + Cette fonction peut être utilisée dans une stratégie de sélection de caractéristiques, telle que la sélection des k caractéristiques les plus pertinentes (valeurs les plus élevées) via la **classe SelectKBest**.
#
# + Par exemple, nous pouvons définir la classe **SelectKBest** pour qu'elle utilise la fonction **f_regression()** et sélectionne toutes
# toutes les caractéristiques, puis transformer les ensembles de formation et de test.

# %%
# example of correlation feature selection for numerical data
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from matplotlib import pyplot

# feature selection
def select_features(X_train, y_train, X_test):
  # configure to select all features
  fs = SelectKBest(score_func=f_regression, k='all')
  # learn relationship from training data
  fs.fit(X_train, y_train)
  # transform train input data
  X_train_fs = fs.transform(X_train)
  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs


# load the dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# what are scores for the features
for i in range(len(fs.scores_)):
  print('Feature %d: %f' % (i, fs.scores_[i]))

# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature 0: 0.009419
# Feature 1: 1.018881
# Feature 2: 1.205187
# Feature 3: 0.000138
# Feature 4: 0.167511
# Feature 5: 5.985083
# Feature 6: 0.062405
# Feature 7: 1.455257
# Feature 8: 0.420384
# Feature 9: 101.392225
# Feature 10: 0.387091
# Feature 11: 1.581124
# Feature 12: 3.014463
# Feature 13: 0.232705
# Feature 14: 0.076281
# Feature 15: 4.299652
# Feature 16: 1.497530
# Feature 17: 0.261242
# Feature 18: 5.960005
# Feature 19: 0.523219
# Feature 20: 0.003365
# Feature 21: 0.024178
# Feature 22: 0.220958
# Feature 23: 0.576770
# Feature 24: 0.627198
# Feature 25: 0.350687
# Feature 26: 0.281877
# Feature 27: 0.584210
# Feature 28: 52.196337
# Feature 29: 0.046855
# Feature 30: 0.147323
# Feature 31: 0.368485
# Feature 32: 0.077631
# Feature 33: 0.698140
# Feature 34: 45.744046
# Feature 35: 2.047376
# Feature 36: 0.786270
# Feature 37: 0.996190
# Feature 38: 2.733533
# Feature 39: 63.957656
# Feature 40: 231.885540
# Feature 41: 1.372448
# Feature 42: 0.581860
# ...

# %% [markdown]
# **14.4 Modélisation avec des caractéristiques sélectionnées**
#
# Il existe de nombreuses techniques différentes pour noter les caractéristiques et sélectionner les caractéristiques en fonction des scores ;
#
# + **Comment savoir laquelle utiliser ?**
#
# + Une approche robuste consiste à évaluer des modèles utilisant différentes méthodes de sélection de caractéristiques (et nombres de caractéristiques) et de sélectionner la méthode qui aboutit à un
# modèle présentant les meilleures performances.
#
# + Dans cette section, nous allons évaluer un modèle de régression linéaire avec toutes les caractéristiques par rapport à un modèle construit à partir des caractéristiques sélectionnées par les statistiques de corrélation et les caractéristiques sélectionnées par l'information mutuelle.
#
# + La régression linéaire est un bon modèle pour tester les méthodes de sélection des caractéristique, car il peut être plus performant si les caractéristiques non pertinentes sont retirées du modèle.

# %% [markdown]
# **14.4.1 Model Built Using All Features**

# %%
# evaluation of a model using all input features
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# load the dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# fit the model
model = LinearRegression()
model.fit(X_train, y_train)

# evaluate the model
yhat = model.predict(X_test)

# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.086

# %% [markdown]
# **14.4.2 Model Built Using Correlation Features**

# %%
# evaluation of a model using 10 features chosen with correlation
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# feature selection
def select_features(X_train, y_train, X_test):

  # configure to select a subset of features
  fs = SelectKBest(score_func=f_regression, k=10)

  # learn relationship from training data
  fs.fit(X_train, y_train)

  # transform train input data
  X_train_fs = fs.transform(X_train)

  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs

# load the dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# fit the model
model = LinearRegression()
model.fit(X_train_fs, y_train)

# evaluate the model
yhat = model.predict(X_test_fs)

# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 2.740

# %%
# evaluation of a model using 88 features chosen with correlation
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# feature selection
def select_features(X_train, y_train, X_test):

  # configure to select a subset of features
  fs = SelectKBest(score_func=f_regression, k=88)

  # learn relationship from training data
  fs.fit(X_train, y_train)

  # transform train input data
  X_train_fs = fs.transform(X_train)
  
  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs

# load the dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# fit the model
model = LinearRegression()
model.fit(X_train_fs, y_train)

# evaluate the model
yhat = model.predict(X_test_fs)

# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.085

# %% [markdown]
# **14.4.3 Model Built Using Mutual Information Features**

# %%
# evaluation of a model using 88 features chosen with mutual information
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# feature selection
def select_features(X_train, y_train, X_test):

  # configure to select a subset of features
  fs = SelectKBest(score_func=mutual_info_regression, k=88)

  # learn relationship from training data
  fs.fit(X_train, y_train)

  # transform train input data
  X_train_fs = fs.transform(X_train)

  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs

# load the dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1
                       )
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# fit the model
model = LinearRegression()
model.fit(X_train_fs, y_train)

# evaluate the model
yhat = model.predict(X_test_fs)

# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.084

# %% [markdown]
# **14.5 Tune the Number of Selected Features**

# %%
# compare different numbers of features selected using mutual information
from sklearn.datasets import make_regression
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# define dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1)

# define the evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# define the pipeline to evaluate
model = LinearRegression()
fs = SelectKBest(score_func=mutual_info_regression)
pipeline = Pipeline(steps=[('sel',fs), ('lr', model)])

# define the grid
grid = dict()
grid['sel__k'] = [i for i in range(X.shape[1]-20, X.shape[1]+1)]

# define the grid search
search = GridSearchCV(pipeline, grid, scoring='neg_mean_absolute_error', n_jobs=-1, cv=cv)

# perform the search
results = search.fit(X, y)

# summarize best
print('Best MAE: %.3f' % results.best_score_)
print('Best Config: %s' % results.best_params_)

# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
  print('>%.3f with: %r' % (mean, param))
# Out:
# Best MAE: -0.082
# Best Config: {'sel__k': 81}
# >-1.100 with: {'sel__k': 80}
# >-0.082 with: {'sel__k': 81}
# >-0.082 with: {'sel__k': 82}
# >-0.082 with: {'sel__k': 83}
# >-0.082 with: {'sel__k': 84}
# >-0.082 with: {'sel__k': 85}
# >-0.082 with: {'sel__k': 86}
# >-0.082 with: {'sel__k': 87}
# >-0.082 with: {'sel__k': 88}
# >-0.083 with: {'sel__k': 89}
# >-0.083 with: {'sel__k': 90}
# >-0.083 with: {'sel__k': 91}
# >-0.083 with: {'sel__k': 92}
# >-0.083 with: {'sel__k': 93}
# >-0.083 with: {'sel__k': 94}
# >-0.083 with: {'sel__k': 95}
# >-0.083 with: {'sel__k': 96}
# >-0.083 with: {'sel__k': 97}
# >-0.083 with: {'sel__k': 98}
# >-0.083 with: {'sel__k': 99}
# >-0.083 with: {'sel__k': 100}

# %%
# compare different numbers of features selected using mutual information
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# define dataset
X, y = make_regression(n_samples=1000, n_features=100, n_informative=10, noise=0.1, random_state=1)

# define number of features to evaluate
num_features = [i for i in range(X.shape[1]-19, X.shape[1]+1)]

# enumerate each number of features
results = list()
for k in num_features:

  # create pipeline
  model = LinearRegression()
  fs = SelectKBest(score_func=mutual_info_regression, k=k)
  pipeline = Pipeline(steps=[('sel',fs), ('lr', model)])

  # evaluate the model
  cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(pipeline, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
  results.append(scores)
  
  # summarize the results
  print('>%d %.3f (%.3f)' % (k, mean(scores), std(scores)))

# plot model performance for comparison
pyplot.boxplot(results, labels=num_features, showmeans=True)
pyplot.show()
# Out:
# >81 -0.082 (0.006)
# >82 -0.082 (0.006)
# >83 -0.082 (0.006)
# >84 -0.082 (0.006)
# >85 -0.082 (0.006)
# >86 -0.082 (0.006)
# >87 -0.082 (0.006)
# >88 -0.082 (0.006)
# >89 -0.083 (0.006)
# >90 -0.083 (0.006)
# >91 -0.083 (0.006)
# >92 -0.083 (0.006)
# >93 -0.083 (0.006)
# >94 -0.083 (0.006)
# >95 -0.083 (0.006)
# >96 -0.083 (0.006)
# >97 -0.083 (0.006)
# >98 -0.083 (0.006)
# >99 -0.083 (0.006)
# >100 -0.083 (0.006)

# %% [markdown]
# **Chapitre 15: Comment utiliser RFE pour la sélection de caractéristiques**
#
# + **Recursive Feature Elimination**, ou **RFE** en abrégé, est un algorithme de sélection de caractéristiques très répandu.
#
# + **RFE** est populaire parce qu'il est facile à configurer et à utiliser, et parce qu'il est efficace pour sélectionner les caractéristiques (colonnes) d'un ensemble de données de formation qui sont les plus pertinentes pour la sélection caractéristiques (colonnes) d'un ensemble de données d'apprentissage qui sont les plus pertinentes pour prédire la variable cible.
#
# + Il existe deux options de configuration importantes lors de l'utilisation de RFE : le choix du nombre de caractéristiques à sélectionner et le choix du nombre de caractéristiques à sélectionner et le choix de l'algorithme utilisé pour aider à choisir les caractéristiques.
#
# + Ces deux hyperparamètres peuvent être explorés, bien que les performances de la méthode ne dépendent pas fortement de ces hyperparamètres.
#
#
# + Dans ce tutoriel, vous découvrirez comment utiliser l'élimination récursive des caractéristiques (RFE) pour la sélection des caractéristiques en Python.
#
#
# **Après avoir terminé ce tutoriel, vous saurez :**
#
# + RFE est une approche efficace pour éliminer les caractéristiques d'un ensemble de données d'entraînement pour la sélection de caractéristiques.
#
# + Comment utiliser RFE pour la sélection de caractéristiques pour la classification et la régression des problèmes.
#
# + Comment explorer le nombre de caractéristiques sélectionnées et l'algorithme enveloppé utilisé par la procédure RFE.
#
# Commençons.
#
# **15.1 Présentation du tutoriel**
#
# Ce tutoriel est divisé en trois parties ; ce sont :
#
# **1. Élimination récursive des caractéristiques**
#
# **2. RFE avec scikit-learn**
#
# **3. Hyperparamètres de RFE**
#
# **15.2 Élimination récursive des caractéristiques**
#
# + **Recursive Feature Elimination**, ou **RFE** en abrégé, est un algorithme de sélection de caractéristiques.
#
# + Un ensemble de données d'apprentissage automatique pour la classification ou la régression est composé de lignes et de colonnes, comme une feuille de calcul.
#
# + Les lignes sont souvent appelées instances et les colonnes sont appelées caractéristiques, par ex. les caractéristiques d'une observation dans un domaine problématique.
#
# + La sélection de caractéristiques fait référence à des techniques qui
# sélectionnent un sous-ensemble des caractéristiques les plus pertinentes (colonnes) pour un ensemble de données.
#
# + Un nombre réduit de caractéristiques peut permettre
# algorithmes d'apprentissage automatique de fonctionner plus efficacement (moins de complexité spatiale ou temporelle) et d'être plus efficaces.
#
# + Certains algorithmes d'apprentissage automatique peuvent être induits en erreur par des caractéristiques d'entrée non pertinentes, ce qui entraîne une baisse des performances prédictives.
#
#
# + **RFE** est un algorithme de sélection de caractéristiques de type **"wrapper"**.
#
# + Cela signifie qu'un algorithme d'apprentissage automatique différent est donné et utilisé dans le noyau de la méthode, qu'il est enveloppé par RFE et qu'il est utilisé pour aider à sélectionner les caractéristiques.
#
# + Cela contraste avec les sélections de caractéristiques basées sur des filtres qui notent chaque caractéristique et sélectionnent les caractéristiques ayant le score le plus élevé (ou le plus faible).
#
# + Techniquement, **RFE** est un algorithme de sélection de caractéristiques de type wrapper qui utilise également en interne la sélection de caractéristiques basée sur des filtres.
#
# + RFE fonctionne en recherchant un sous-ensemble de caractéristiques en commençant par toutes les caractéristiques de l'ensemble de données d'apprentissage et en éliminant des caractéristiques jusqu'à ce qu'elles soient éliminées.
#
# + Ceci est réalisé en adaptant l'algorithme d'apprentissage automatique utilisé au cœur du modèle, en classant les caractéristiques par ordre d'importance et en éliminant les moins importantes et en ajustant à nouveau le modèle.
#
# + Ce processus est est répété jusqu'à ce qu'il reste un nombre spécifié de caractéristiques.
#
# + Lorsque le modèle complet est créé, une mesure de l'importance des variables est calculée qui classe les prédicteurs du plus important au moins important. [...]
#
# + A chaque étape de la recherche, les prédicteurs les moins importants sont éliminés itérativement avant de reconstruire le modèle.
# modèle.
#
#
# + Les caractéristiques sont notées soit à l'aide du modèle d'apprentissage automatique fourni (p. ex. certains algorithmes comme les arbres de décision offrent des scores d'importance) ou en utilisant une méthode statistique.
#
# + Les calculs d'importance peuvent être basés sur un modèle (par exemple, le critère d'importance de la forêt aléatoire) ou utiliser une approche plus générale indépendante du modèle complet.
#
#
# + Maintenant que nous sommes familiarisés avec la procédure RFE, examinons comment nous pouvons l'utiliser dans nos projets.
#
# **15.3 RFE avec scikit-learn**
#
# + La bibliothèque d'apprentissage automatique scikit-learn Python fournit une implémentation de RFE pour l'apprentissage automatique par le biais de la classe RFE de scikit-learn.
#
# + RFE est une transformation. Pour l'utiliser, il faut d'abord configurer la classe est configurée avec l'algorithme choisi spécifié via l'argument estimateur et le nombre de caractéristiques à sélectionner via l'argument n caractéristiques à sélectionner.
#
#
# + RFE nécessite un algorithme imbriqué qui est utilisé pour fournir les scores d'importance des caractéristiques, tel qu'un arbre de décision.
#
# + L'algorithme imbriqué utilisé dans RFE ne doit pas nécessairement être l'algorithme qui est utilisé dans le processus de sélection.
#
# **15.3. RFE avec scikit-learn**
#
# + s'adapter aux caractéristiques sélectionnées ; différents algorithmes peuvent être utilisés.
#
# + Une fois configurée, la classe doit être ajustée sur un ensemble de données d'entraînement pour sélectionner les caractéristiques en appelant la fonction **fit()**.
#
# + Après l'ajustement de la classe est ajustée, le choix des variables d'entrée est visible via l'attribut support qui fournit un Vrai ou un Faux pour chaque variable d'entrée.
#
# + Il peut ensuite être appliqué aux ensembles de données de formation et de test en appelant la fonction **transform()**.

# %%
...
# define the method
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=3)
# fit the model
rfe.fit(X, y)
# transform the data
X, y = rfe.transform(X, y)

# %% [markdown]
# **15.3.1 RFE for Classification**

# %%
# evaluate RFE for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# create pipeline
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=5)
model = DecisionTreeClassifier()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X, y, scoring='accuracy', cv=cv, n_jobs=-1)

# report performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.889 (0.034)

# %%
# make a prediction with an RFE pipeline
from sklearn.datasets import make_classification
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5,
random_state=1)
# create pipeline
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=5)
model = DecisionTreeClassifier()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# fit the model on all available data
pipeline.fit(X, y)
# make a prediction for one example
data = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = pipeline.predict(data)
print('Predicted Class: %d' % (yhat))
# Out:
# Predicted Class: 1

# %% [markdown]
# **15.3.2 RFE for Regression**

# %%
# evaluate RFE for regression
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline

# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)

# create pipeline
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
model = DecisionTreeRegressor()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# evaluate model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X, y, scoring='neg_mean_absolute_error', cv=cv,n_jobs=-1)

# report performance
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -27.189 (2.746)

# %%
# make a regression prediction with an RFE pipeline
from sklearn.datasets import make_regression
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline

# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)

# create pipeline
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
model = DecisionTreeRegressor()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# fit the model on all available data
pipeline.fit(X, y)

# make a prediction for one example
data = [[-2.02220122, 0.31563495, 0.82797464, -0.30620401, 0.16003707, -1.44411381, 0.87616892, -0.50446586, 0.23009474, 0.76201118]]
yhat = pipeline.predict(data)
print('Predicted: %.3f' % (yhat))
# Out:
# Predicted: -84.288

# %% [markdown]
# **15.4 RFE Hyperparameters**

# %% [markdown]
# ***15.4.1 Explore Number of Features***

# %%
# explore the number of selected features for RFE
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# get the dataset
def get_dataset():
  X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5,
  random_state=1)
  return X, y

# get a list of models to evaluate
def get_models():
  models = dict()
  for i in range(2, 10):
    rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=i)
    model = DecisionTreeClassifier()
    models[str(i)] = Pipeline(steps=[('s',rfe),('m',model)])
  return models

# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
  cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
  return scores

# define dataset
X, y = get_dataset()
# get the models to evaluate
models = get_models()

# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
  scores = evaluate_model(model, X, y)
  results.append(scores)
  names.append(name)
  print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))

# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >2 0.718 (0.040)
# >3 0.825 (0.035)
# >4 0.874 (0.032)
# >5 0.886 (0.034)
# >6 0.887 (0.029)
# >7 0.884 (0.032)
# >8 0.885 (0.028)
# >9 0.887 (0.027)

# %% [markdown]
# **15.4.2 Automatically Select the Number of Features**

# %%
# automatically select the number of features for RFE
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# create pipeline
rfe = RFECV(estimator=DecisionTreeClassifier())
model = DecisionTreeClassifier()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X, y, scoring='accuracy', cv=cv, n_jobs=-1)

# report performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.883 (0.028)

# %% [markdown]
# **15.4.3 Which Features Were Selected**

# %%
# report which features were selected by RFE
from sklearn.datasets import make_classification
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# define RFE
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=5)

# fit RFE
rfe.fit(X, y)

# summarize all features
for i in range(X.shape[1]):
  print('Column: %d, Selected=%s, Rank: %d' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected=False, Rank: 4
# Column: 1, Selected=False, Rank: 5
# Column: 2, Selected=True, Rank: 1
# Column: 3, Selected=True, Rank: 1
# Column: 4, Selected=True, Rank: 1
# Column: 5, Selected=False, Rank: 6
# Column: 6, Selected=True, Rank: 1
# Column: 7, Selected=False, Rank: 3
# Column: 8, Selected=True, Rank: 1
# Column: 9, Selected=False, Rank: 2

# %% [markdown]
# **15.4.4 Explore Base Algorithm**

# %%
# explore the algorithm wrapped by RFE
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# get the dataset
def get_dataset():
  X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5,
  random_state=1)
  return X, y

# get a list of models to evaluate
def get_models():
  models = dict()
  # lr
  rfe = RFE(estimator=LogisticRegression(), n_features_to_select=5)
  model = DecisionTreeClassifier()
  models['lr'] = Pipeline(steps=[('s',rfe),('m',model)])
  # perceptron
  rfe = RFE(estimator=Perceptron(), n_features_to_select=5)
  model = DecisionTreeClassifier()
  models['per'] = Pipeline(steps=[('s',rfe),('m',model)])
  # cart
  rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=5)
  model = DecisionTreeClassifier()
  models['cart'] = Pipeline(steps=[('s',rfe),('m',model)])
  # rf
  rfe = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)
  model = DecisionTreeClassifier()
  models['rf'] = Pipeline(steps=[('s',rfe),('m',model)])
  # gbm
  rfe = RFE(estimator=GradientBoostingClassifier(), n_features_to_select=5)
  model = DecisionTreeClassifier()
  models['gbm'] = Pipeline(steps=[('s',rfe),('m',model)])
  return models

# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
  cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
  return scores

# define dataset
X, y = get_dataset()

# get the models to evaluate
models = get_models()

# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
  scores = evaluate_model(model, X, y)
  results.append(scores)
  names.append(name)
  print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
  
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >lr 0.889 (0.033)
# >per 0.845 (0.035)
# >cart 0.888 (0.029)
# >rf 0.854 (0.038)
# >gbm 0.884 (0.030)

# %% [markdown]
# **Chapitre 16 :Comment utiliser l'importance des caractéristiques**
#
# + L'importance des caractéristiques fait référence aux techniques qui attribuent un score aux caractéristiques d'entrée en fonction de leur utilité pour prédire une variable cible.
#
#
# + Il existe de nombreux types et sources de scores d'importance des caractéristiques, bien que les exemples les plus courants incluent les **scores de corrélation statistique**, **les coefficients calculés** dans le cadre de **modèles linéaires**, **d'arbres de décision** et de **scores d'importance de permutation**.
#
# + Les scores d'importance des caractéristiques jouent un rôle important dans un projet de modélisation prédictive.
#
# + les données et le modèle, ainsi que la base de la réduction de la dimensionnalité et des sélection des caractéristiques qui peuvent améliorer l'efficacité d'un modèle prédictif sur le problème.
#
# + Dans ce tutoriel, vous découvrirez les scores d'importance des caractéristiques pour l'apprentissage automatique en Python.
#
# **Après avoir terminé ce tutoriel, vous saurez** :
#
# + Le rôle de l'importance des caractéristiques dans un problème de modélisation prédictive.
#
# + Comment calculer et examiner l'importance des caractéristiques des modèles linéaires et des arbres de décision.
#
# + Comment calculer et examiner les scores d'importance des caractéristiques de permutation.
#
# Commençons.
#
# **16.1 Présentation du tutoriel**
#
# Ce tutoriel est divisé en sept parties :
#
# **1. Importance des caractéristiques**
#
# **2. Jeux de données de test**
#
# **3. Coefficients comme importance de la caractéristique**
#
# **4. Importance des caractéristiques de l'arbre de décision**
#
# **5. Importance des caractéristiques de permutation**
#
# **6. Sélection de caractéristiques avec importance**
#
# **7. Questions communes**
#
# **16.2 Importance des caractéristiques**
#
# + L'importance des caractéristiques fait référence à une classe de techniques permettant d'attribuer des notes aux caractéristiques d'entrée d'un modèle prédictif qui indique l'importance relative de chaque caractéristique lors d'une prédiction.
#
# + Les scores d'importance des caractéristiques peuvent être calculés pour des problèmes qui impliquent la prédiction d'une valeur numérique, appelée **régression**, et les problèmes qui impliquent la prédiction d'une étiquette de classe, appelée **classification**.
#
# + Les scores sont utiles et peuvent être utilisés dans toute une série de situations dans un problème de prédiction, comme par exemple
#
# + Mieux comprendre les données.
# + Mieux comprendre un modèle.
# + Réduire le nombre de caractéristiques d'entrée.
#
# + Les scores d'importance des caractéristiques peuvent donner un aperçu de l'ensemble des données.
#
# + Les scores relatifs peuvent mettre en évidence les caractéristiques les plus pertinentes pour la cible, et inversement, les caractéristiques les moins pertinentes.
#
# + Ces résultats peuvent être interprétés par un expert du domaine et servir de base à la collecte de données supplémentaires ou différentes.
#
# + Les scores d'importance des caractéristiques peuvent donner un aperçu du modèle.
#
# + La plupart des scores d'importance des caractéristiques sont calculés par un modèle prédictif qui a été adapté à l'ensemble de données.
#
# + L'inspection du score d'importance fournit des informations sur ce modèle spécifique et sur les caractéristiques les plus importantes et les moins importantes pour le modèle lors d'une prédiction.
#
# + Il s'agit d'un type d'interprétation de modèle qui peut être effectué pour les modèles qui le supportent.
#
# + L'importance des caractéristiques peut être utilisée pour améliorer un modèle prédictif.
#
# +  Ceci peut être réalisé en utilisant les scores d'importance pour sélectionner les caractéristiques à supprimer (scores les plus bas) ou les caractéristiques à conserver (scores les plus élevés).
#
# + Il s'agit d'un type de sélection de caractéristiques qui peut simplifier le problème modélisé, accélérer le processus de modélisation (la suppression de caractéristiques est appelée réduction de la dimensionnalité) et, dans certains cas, améliorer la qualité de la modélisation.
#
# + Souvent, nous souhaitons quantifier la force de la relation entre les prédicteurs  et le résultat. [...] Classer les prédicteurs de cette manière peut être très utile lorsque l'on pour passer au crible de grandes quantités de données.
#
# + Les scores d'importance des caractéristiques peuvent être transmis à un modèle enveloppant, tel que la classe **SelectFromModel**
# pour effectuer une sélection de caractéristiques.
#
# + Chaque technique d'importance des caractéristiques a le potentiel de classer l'importance des caractéristiques d'entrée, créant ainsi une vision différente des données.
#
# + En tant que telle, il n'y a pas de meilleure technique d'importance des caractéristiques.
#
# + Si l'objectif est de trouver le sous-ensemble de caractéristiques d'entrée qui donne les meilleures performances du modèle, il faut essayer une série de techniques de sélection des caractéristiques, y compris différentes méthodes d'importance des caractéristiques.
#
# + Il existe de nombreuses façons de calculer les scores d'importance des caractéristiques et de nombreux modèles qui peuvent être utilisés à cette fin.
#
# + Néanmoins, les scores entre les méthodes d'importance des caractéristiques ne peuvent pas être comparés directement.
#
# + Au lieu de cela, les scores de chaque variable d'entrée sont relatifs les uns aux autres pour une méthode donnée.
#
# + Dans ce tutoriel, nous examinerons trois types principaux de méthodes plus avancées d'importance des caractéristiques à partir des coefficients du modèle.
#
# + Importance des caractéristiques à partir des arbres de décision.
# + Importance de la caractéristique à partir du test de permutation.
# + Examinons-les de plus près.
#
# **16.3 Jeux de données de test**
#
# Avant de nous plonger dans le vif du sujet, définissons quelques ensembles de données de test que nous pouvons utiliser comme base pour démontrer et explorer les scores d'importance des caractéristiques.
#
# + Chaque problème de test comporte cinq caractéristiques informatives et cinq caractéristiques informatives et cinq autres non informatives, et il peut être intéressant de voir quelles méthodes sont cohérentes pour trouver ou différencier les caractéristiques en fonction de leur importance.
#
# **16.3.1 Jeu de données de classification**
#
# + Nous allons utiliser la fonction **make_classification()** pour créer un jeu de données de classification binaire de test.
#
# + Le jeu de données comprendra 1 000 exemples, avec 10 caractéristiques d'entrée, dont cinq seront informatives et les cinq autres seront redondantes.
#
# + Nous fixerons la graine de nombre aléatoire afin de nous assurer que nous obtenons les mêmes exemples à chaque fois que le code est exécuté.
#
# + Un exemple de création et de résumé de l'ensemble de données est présenté ci-dessous.

# %%
# test classification dataset
from sklearn.datasets import make_classification
# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5,
random_state=1)
# summarize the dataset
print(X.shape, y.shape)
# Out:
# (1000, 10) (1000,)

# %% [markdown]
# **16.3.2 Regression Dataset**

# %%
# test regression dataset
from sklearn.datasets import make_regression
# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)
# summarize the dataset
print(X.shape, y.shape)
# Out:
# (1000, 10) (1000,)

# %% [markdown]
# **16.4 Coefficients as Feature Importance**
#
# ***16.4.1 Linear Regression Feature Importance***

# %%
# linear regression feature importance
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot

# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)

# define the model
model = LinearRegression()

# fit the model
model.fit(X, y)

# get importance
importance = model.coef_

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))
  
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: -0.00000
# Feature: 1, Score: 12.44483
# Feature: 2, Score: -0.00000
# Feature: 3, Score: -0.00000
# Feature: 4, Score: 93.32225
# Feature: 5, Score: 86.50811
# Feature: 6, Score: 26.74607
# Feature: 7, Score: 3.28535
# Feature: 8, Score: -0.00000
# Feature: 9, Score: 0.00000

# %% [markdown]
# ***16.4.2 Logistic Regression Feature Importance***

# %%
# logistic regression for feature importance
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# define the model
model = LogisticRegression()

# fit the model
model.fit(X, y)

# get importance
importance = model.coef_[0]

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))
  
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.16320
# Feature: 1, Score: -0.64301
# Feature: 2, Score: 0.48497
# Feature: 3, Score: -0.46190
# Feature: 4, Score: 0.18432
# Feature: 5, Score: -0.11978
# Feature: 6, Score: -0.40602
# Feature: 7, Score: 0.03772
# Feature: 8, Score: -0.51785
# Feature: 9, Score: 0.26540

# %% [markdown]
# **16.5 Importance des caractéristiques des arbres décisionnels**
#
# + **Les algorithmes d'arbre de décision** comme **les arbres de classification** et de **régression (CART)** offrent des scores d'importance basés sur la réduction du critère utilisé pour sélectionner les points de séparation, comme le Gini ou l'entropie.
#
# + Cette même approche peut être utilisée pour les ensembles d'arbres décisionnels, tels que la forêt aléatoire et les algorithmes d'amplification par **gradient stochastique**.
#
# Voyons un exemple concret de chacun d'entre eux.
#
# **16.5.1 Importance des caractéristiques de CART**
#
# + Nous pouvons utiliser **l'algorithme CART** pour l'importance des caractéristiques, implémenté dans scikit-learn sous la forme des modules
# classes **DecisionTreeRegressor** et **DecisionTreeClassifier**.
#
# + Après avoir été ajusté, le modèle fournit une propriété d'importance des caractéristiques à laquelle on peut accéder pour récupérer les scores d'importance relative pour chaque caractéristique d'entrée.
#
# Voyons un exemple pour la régression et la classification.
#
# **16.5. Importance des caractéristiques de l'arbre de décision**
#
# + **Importance des caractéristiques de régression CART**
#
# + L'exemple complet d'ajustement d'un **DecisionTreeRegressor** et de récapitulation des **scores d'importance** des calculés est présenté ci-dessous.

# %%
# decision tree for feature importance on a regression problem
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from matplotlib import pyplot

# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)

# define the model
model = DecisionTreeRegressor()

# fit the model
model.fit(X, y)

# get importance
importance = model.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))
  
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.00277
# Feature: 1, Score: 0.00492
# Feature: 2, Score: 0.00198
# Feature: 3, Score: 0.00149
# Feature: 4, Score: 0.51715
# Feature: 5, Score: 0.43802
# Feature: 6, Score: 0.02734
# Feature: 7, Score: 0.00268
# Feature: 8, Score: 0.00265
# Feature: 9, Score: 0.00100

# %% [markdown]
# **CART Classification Feature Importance**

# %%
# decision tree for feature importance on a classification problem
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5,random_state=1)

# define the model
model = DecisionTreeClassifier()

# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))

# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.01676
# Feature: 1, Score: 0.01593
# Feature: 2, Score: 0.18497
# Feature: 3, Score: 0.30447
# Feature: 4, Score: 0.09079
# Feature: 5, Score: 0.01019
# Feature: 6, Score: 0.17313
# Feature: 7, Score: 0.03602
# Feature: 8, Score: 0.12992
# Feature: 9, Score: 0.03783

# %% [markdown]
# **16.5.2 Random Forest Feature Importance**
#
# **Random Forest Regression Feature Importance**

# %%
# random forest for feature importance on a regression problem
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot

# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)

# define the model
model = RandomForestRegressor()

# fit the model
model.fit(X, y)

# get importance
importance = model.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))

# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.00294
# Feature: 1, Score: 0.00551
# Feature: 2, Score: 0.00288
# Feature: 3, Score: 0.00283
# Feature: 4, Score: 0.53166
# Feature: 5, Score: 0.41873
# Feature: 6, Score: 0.02646
# Feature: 7, Score: 0.00297
# Feature: 8, Score: 0.00329
# Feature: 9, Score: 0.00274

# %% [markdown]
# **Random Forest Classification Feature Importance**

# %%
# random forest for feature importance on a classification problem
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# define the model
model = RandomForestClassifier()

# fit the model
model.fit(X, y)

# get importance
importance = model.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))

# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.06231
# Feature: 1, Score: 0.12288
# Feature: 2, Score: 0.15275
# Feature: 3, Score: 0.18128
# Feature: 4, Score: 0.08394
# Feature: 5, Score: 0.10818
# Feature: 6, Score: 0.10522
# Feature: 7, Score: 0.05171
# Feature: 8, Score: 0.09015
# Feature: 9, Score: 0.04158

# %% [markdown]
# **16.6 Importance des caractéristiques de permutation**
#
# + **L'importance des caractéristiques par permutation** est une technique de calcul des scores d'importance relative qui est indépendante du modèle utilisé.
#
# + Tout d'abord, un modèle est ajusté sur l'ensemble de données, par exemple un modèle qui ne prend pas en charge les scores d'importance des caractéristiques natives.
#
# + Ensuite, le modèle est utilisé pour faire des prédictions
# sur un ensemble de données, bien que les valeurs d'une caractéristique (colonne) dans l'ensemble de données soient brouillées.
#
# + Cette opération est répété pour chaque caractéristique de l'ensemble de données. Ensuite, tout ce processus est répété 3, 5, 10 fois ou plus.
#
# + Le résultat est un score d'importance moyen pour chaque élément d'entrée (et la distribution des scores compte tenu des répétitions).
#
# + Cette approche peut être utilisée pour la régression ou la classification.
#
# + performance soit choisie comme base du score d'importance, comme l'erreur quadratique moyenne pour la régression et la précision pour la classification.
#
# + La sélection de caractéristiques par permutation peut être utilisée via la fonction **permutation importance()** qui prend un modèle adapté, un ensemble de données (ensemble de données de formation ou de
# test) et une fonction de notation.
#
# + Examinons cette approche de la sélection de caractéristiques avec un
# algorithme qui ne prend pas en charge la sélection de caractéristiques de manière native, notamment les k-voisins les plus proches.

# %% [markdown]
# **16.6.1 Permutation Feature Importance for Regression**

# %%
# permutation feature importance with knn for regression
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.inspection import permutation_importance
from matplotlib import pyplot

# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)

# define the model
model = KNeighborsRegressor()

# fit the model
model.fit(X, y)

# perform permutation importance
results = permutation_importance(model, X, y, scoring='neg_mean_squared_error')

# get importance
importance = results.importances_mean

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))
  
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 151.50057
# Feature: 1, Score: 336.69506
# Feature: 2, Score: 150.79664
# Feature: 3, Score: 64.17248
# Feature: 4, Score: 9545.69552
# Feature: 5, Score: 8061.68427
# Feature: 6, Score: 902.93188
# Feature: 7, Score: 150.30130
# Feature: 8, Score: 125.25479
# Feature: 9, Score: 72.87282

# %% [markdown]
# **16.6.2 Permutation Feature Importance for Classification**

# %%
# permutation feature importance with knn for classification
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.inspection import permutation_importance
from matplotlib import pyplot

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# define the model
model = KNeighborsClassifier()

# fit the model
model.fit(X, y)

# perform permutation importance
results = permutation_importance(model, X, y, scoring='accuracy')

# get importance
importance = results.importances_mean

# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))
  
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.04720
# Feature: 1, Score: 0.06120
# Feature: 2, Score: 0.05400
# Feature: 3, Score: 0.09320
# Feature: 4, Score: 0.05340
# Feature: 5, Score: 0.05760
# Feature: 6, Score: 0.06940
# Feature: 7, Score: 0.05380
# Feature: 8, Score: 0.05280
# Feature: 9, Score: 0.03300

# %% [markdown]
# **16.7 Sélection des caractéristiques avec l'importance**
#
# + Les scores d'importance des caractéristiques peuvent être utilisés pour aider à interpréter les données, mais ils peuvent également être utilisés directement pour aider à classer et sélectionner les caractéristiques les plus utiles à un modèle prédictif.
#
#
# + Nous pouvons le démontrer à l'aide d'un petit exemple.
#
# + Rappelons que notre ensemble de données synthétiques comporte 1 000 exemples, chacun avec 10 variables d'entrée, dont cinq sont des variables d'entrée.
#
# + Nous pouvons utiliser les scores d'importance des caractéristiques pour aider à sélectionner les cinq variables qui sont pertinentes
# et les utiliser uniquement comme entrées d'un modèle prédictif.
#
# + Tout d'abord, nous pouvons diviser l'ensemble de données de formation en ensembles de formation et de test et former un modèle sur l'ensemble de données de formation.
#
# + l'ensemble de données d'apprentissage, faire des prédictions sur l'ensemble de test et évaluer le résultat en utilisant la précision de la classification.
#
# + Nous utiliserons un modèle de régression logistique comme modèle prédictif.
#
# + Cela fournit une référence pour la comparaison lorsque nous supprimons certaines caractéristiques en utilisant les scores d'importance des caractéristiques.
#
# + Le site exemple complet d'évaluation d'un modèle de régression logistique utilisant toutes les caractéristiques en entrée sur notre
# ensemble de données synthétiques est présenté ci-dessous

# %%
# evaluation of a model using 5 features chosen with random forest importance
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# feature selection
def select_features(X_train, y_train, X_test):
  # configure to select a subset of features
  fs = SelectFromModel(RandomForestClassifier(n_estimators=1000), max_features=5)
  # learn relationship from training data
  fs.fit(X_train, y_train)
  # transform train input data
  X_train_fs = fs.transform(X_train)
  # transform test input data
  X_test_fs = fs.transform(X_test)
  return X_train_fs, X_test_fs, fs

# define the dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# fit the model
model = LogisticRegression(solver='liblinear')
model.fit(X_train_fs, y_train)

# evaluate the model
yhat = model.predict(X_test_fs)

# evaluate predictions
accuracy = accuracy_score(y_test, yhat)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 84.55

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# #***Chapter :Basic Data Cleaning***
#
# + **Le nettoyage des données** est une étape cruciale dans tout projet d'apprentissage automatique.
#
# + Dans les données tabulaires, il existe de nombreuses techniques d'analyse statistique et de visualisation des données que vous pouvez utiliser pour explorer vos données afin d'identifier les opérations de nettoyage des données que vous pouvez souhaiter effectuer.
#
# + Avant de passer aux méthodes sophistiquées, il existe des opérations de nettoyage de données très basiques que vous que vous devriez probablement effectuer sur chaque projet d'apprentissage automatique.
#
# + Ces opérations sont tellement basiques qu'elles sont souvent négligées par des personnes expérimentées.
#
# + Pourtant, elles sont si critiques que si elles sont omises, les modèles peuvent se briser ou rapporter des résultats de performance trop optimistes.
#
# + Dans ce tutoriel, vous découvrirez le nettoyage de base des données que vous devez toujours effectuer sur votre ensemble de données.
#
#
# + Après avoir terminé ce tutoriel, vous saurez :
#
# + Comment identifier et prendre en compte les variables de colonnes ayant très peu de valeurs uniques.
#
# + Comment identifier et supprimer les lignes qui contiennent des observations en double.
#
# **Commençons.**
#
# **1 Présentation du tutoriel**
#
# Ce tutoriel est divisé en sept parties ; ce sont :
#
# **1. Ensembles de données désordonnés**
#
# **2. Identifier les colonnes qui contiennent une seule valeur**
#
# **3. Supprimer les colonnes qui contiennent une seule valeur**
#
# **4. Considérer les colonnes qui ont très peu de valeurs**
#
# **5. Supprimez les colonnes qui ont une faible variance.**
#
# **6. Identifiez les rangées qui contiennent des données en double.**
#
# **7. Supprimez les lignes qui contiennent des données en double.**
#
# ***2) Ensembles de données désordonnés***
#
# + **Le nettoyage des données** consiste à identifier et à corriger les erreurs dans l'ensemble de données qui peuvent avoir un impact négatif sur un modèle prédictif.
#
# + **Le nettoyage des données** est utilisé pour désigner toutes sortes de tâches et d'activités visant à détecter et à réparer les erreurs dans les données.
#
# + Bien qu'il soit d'une importance cruciale, le nettoyage des données n'est pas passionnant et ne fait pas appel à des techniques sophistiquées. Il suffit d'avoir une bonne connaissance de l'ensemble des données.
#
# + Nettoyer vos données n'est pas la plus glamour des tâches, mais c'est une partie essentielle de la manipulation des données.
#
# + Savoir comment nettoyer et assembler vos données correctement
# vous distinguera des autres dans votre domaine.
#
# + Il existe de nombreux types d'erreurs dans un ensemble de données, bien que les erreurs les plus simples soient les suivantes
# comprennent les colonnes qui ne contiennent pas beaucoup d'informations et les lignes dupliquées.
#
# + Avant de nous plonger dans l'identification et la correction des données désordonnées, définissons quelques ensembles de données désordonnées.
#
#
# + Nous utiliserons deux ensembles de données comme base pour ce tutoriel : **l'ensemble de données sur les marées noires et l'ensemble de données sur les fleurs d'iris**.
#
# **2.1)  Jeu de données sur les marées noires**
#
# + Le jeu de données sur les marées noires est un jeu de données d'apprentissage automatique standard.
#
# + La tâche consiste à prédire si le patch contient une marée noire ou non, par exemple à cause d'un déversement illégal ou accidentel de pétrole dans l'océan, d'un accident de pêche ou d'une catastrophe naturelle, étant donné un vecteur qui décrit le contenu d'une parcelle d'une image satellite.
#
# + Il y a 937 cas. Chaque cas est composé de 48 caractéristiques numériques dérivées de la vision par ordinateur, d'un numéro de parcelle et d'un numéro d'identification.
#
# + Le cas normal est l'absence de marée noire et l'étiquette de classe 0, tandis qu'une marée noire est indiquée par une étiquette de classe de 1. 896 cas d'absence de marée noire et 41 cas de marée noire ont été enregistrés.
#
# + Vous pouvez en savoir plus sur ce jeu de données ici :
#
#   + Jeu de données sur les marées noires (oil-spill.csv)
#
#   + Description de l'ensemble de données sur les marées noires (oil-spill.names)
#
#
#
# 1) https://raw.githubusercontent.com/jbrownlee/Datasets/master/oil-spill.csv
#
# 2) https://raw.githubusercontent.com/jbrownlee/Datasets/master/oil-spill.name
#
#
# **2.2 Ensemble de données sur les fleurs d'iris**
#
# + Le jeu de données dit des fleurs d'iris est un autre jeu de données d'apprentissage automatique standard.
#
# + Ce jeu de données consiste à prédire l'espèce de fleur à partir de mesures de fleurs d'iris en centimètres.
#
# + Il s'agit d'un problème de classification multi-classes.
#
# + Le nombre d'observations pour chaque classe est équilibré.
#
# + Il y a 150 observations avec 4 variables d'entrée et 1 variable de sortie. Vous pouvez accéder à l'ensemble de données ici :
#
# 3) https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv
#
# 4) https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.names
#
#
# **3 Identifier les colonnes qui contiennent une seule valeur**

# %%
# Chargement de données et identification des colonnes avec numpy
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/oil-spill.csv'
# summarize the number of unique values for each column using numpy
from numpy import loadtxt
from numpy import unique
# load the dataset
data = loadtxt(filename, delimiter=',')
# summarize the number of unique values in each column
for i in range(data.shape[1]):
  print(i, len(unique(data[:, i])))
# Out:
# 0 238
# 1 297
# 2 927
# 3 933
# 4 179
# 5 375
# 6 820
# 7 618
# 8 561
# 9 57
# 10 577
# 11 59
# 12 73
# 13 107
# 14 53
# 15 91
# 16 893
# 17 810
# 18 170
# 19 53
# 20 68
# 21 9
# 22 1
# 23 92
# 24 9
# 25 8
# 26 9
# 27 308
# 28 447
# 29 392
# 30 107
# 31 42
# 32 4
# 33 45
# 34 141
# 35 110
# 36 3
# 37 758
# 38 9
# 39 9
# 40 388
# 41 220
# 42 644
# 43 649
# 44 499
# 45 2
# 46 937
# 47 169
# 48 286
# 49 2

# %%
# summarize the number of unique values for each column using numpy
from pandas import read_csv
# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/oil-spill.csv'
df = read_csv(filename, header=None)
# summarize the number of unique values in each column
print(df.nunique())
# Out:
# 0     238
# 1     297
# 2     927
# 3     933
# 4     179
# 5     375
# 6     820
# 7     618
# 8     561
# 9      57
# 10    577
# 11     59
# 12     73
# 13    107
# 14     53
# 15     91
# 16    893
# 17    810
# 18    170
# 19     53
# 20     68
# 21      9
# 22      1
# 23     92
# 24      9
# 25      8
# 26      9
# 27    308
# 28    447
# 29    392
# 30    107
# 31     42
# 32      4
# 33     45
# 34    141
# 35    110
# 36      3
# 37    758
# 38      9
# 39      9
# 40    388
# 41    220
# 42    644
# 43    649
# 44    499
# 45      2
# 46    937
# 47    169
# 48    286
# 49      2
# dtype: int64

# %% [markdown]
# **3) Supprimer les colonnes qui contiennent une seule valeur**

# %%
# load the dataset
filename = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/oil-spill.csv'
df = read_csv(filename, header=None)
print(df.shape)
# get number of unique values for each column
counts = df.nunique()
# record columns to delete
to_del = [i for i,v in enumerate(counts) if v == 1]
print(to_del)
# drop useless columns
df.drop(to_del, axis=1, inplace=True)
print(df.shape)
# Out:
# (937, 50)
# [22]
# (937, 49)

# %% [markdown]
# ###**4) Consider Columns That Have Very Few Values(English)/Tenir compte des colonnes qui ont très peu de valeurs(French)**

# %%
# summarize the percentage of unique values for each column using numpy
from numpy import loadtxt
from numpy import unique
# load the dataset
data = loadtxt("/content/oil-spill.csv", delimiter=",") # summarize the number of unique values in each column
for i in range(data.shape[1]):
  num = len(unique(data[:, i]))
  percentage = float(num) / data.shape[0] * 100
  print("%d, %d, %.1f%%" % (i, num, percentage))
# Out:
# 0, 238, 25.4%
# 1, 297, 31.7%
# 2, 927, 98.9%
# 3, 933, 99.6%
# 4, 179, 19.1%
# 5, 375, 40.0%
# 6, 820, 87.5%
# 7, 618, 66.0%
# 8, 561, 59.9%
# 9, 57, 6.1%
# 10, 577, 61.6%
# 11, 59, 6.3%
# 12, 73, 7.8%
# 13, 107, 11.4%
# 14, 53, 5.7%
# 15, 91, 9.7%
# 16, 893, 95.3%
# 17, 810, 86.4%
# 18, 170, 18.1%
# 19, 53, 5.7%
# 20, 68, 7.3%
# 21, 9, 1.0%
# 22, 1, 0.1%
# 23, 92, 9.8%
# 24, 9, 1.0%
# 25, 8, 0.9%
# 26, 9, 1.0%
# 27, 308, 32.9%
# 28, 447, 47.7%
# 29, 392, 41.8%
# 30, 107, 11.4%
# 31, 42, 4.5%
# 32, 4, 0.4%
# 33, 45, 4.8%
# 34, 141, 15.0%
# 35, 110, 11.7%
# 36, 3, 0.3%
# 37, 758, 80.9%
# 38, 9, 1.0%
# 39, 9, 1.0%
# 40, 388, 41.4%
# 41, 220, 23.5%
# 42, 644, 68.7%
# 43, 649, 69.3%
# 44, 499, 53.3%
# 45, 2, 0.2%
# 46, 937, 100.0%
# 47, 169, 18.0%
# 48, 286, 30.5%
# 49, 2, 0.2%
